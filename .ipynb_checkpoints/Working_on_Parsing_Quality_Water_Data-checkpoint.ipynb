# %% [markdown]
# # Next Steps (as of October 20, 2018)
# So we got the file put into a potentially readable format for a bipartite network in networkx, but we still have a lot of work to do!
#
# **Audrey**
# * Figure out what format this file needs to be in in order to load into networkx as a bipartite
# * Create a bipartite network!
#
# **Cassie**
# * Figure out and get the thresholds for pollutants in California (esp. if they're different than what we have)
# * Put those thresholds into a format that can be easily used by the code we've written

# %% [markdown]
# # Water Quality Network
# For our network project, Cassie and I are thinking of creating a bipartite network where the nodes are pollutants and the links are water facilities whose measurements of those pollutants are above the threshold. By doing this linking, we hope to see what the biggest pollutants are, how pollutants might connect to one another, and if there are any pollutants that we should be worried about.

# %% [markdown]
# ## Data Sources
# We got our data from USGS (U.S. Geological Survey). I'll need to get the exact link later.

# %% [markdown]
# ### MUST PIP INSTALL
# * numpy
# * pandas
# * matplotlib
# * xlrd

# %%
import re
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from networkx.algorithms import bipartite
# %matplotlib inline

# %% [markdown]
# ## Looking at the Quality data
# Since I'm not too familiar with the data, let's load it in and take a look. There's some preliminary things that I do know, which will be come prevelant when you look at the code. For instance, you can break up the code into chunks by splitting on instances of "#\n". The # comes from the file header and most "sections" within the header are separated by # followed by a new line. The last item of the split is the actual data.
#
# Let's start by loading in everything!

# %%
def load_quality_quality_data(file_name):
    quality_data = []
    with open(file_name, 'r') as file:
        quality_data = file.read().split("#\n")

    if not quality_data:
        print("File {} was unable to be read.".format(file_name))
    return quality_data

# %%
file_name = "LA_Water_Quality_Data.txt"
quality_data = load_quality_data(file_name)
print("Number of sections:", len(quality_data))
print("2nd section:", quality_data[2], sep = "\n")
print("Number of characters in actual data:", len(quality_data[15]))
# Out:
# Number of sections: 16
# 2nd section:
# # U.S. Geological Survey
# #
# # This file contains selected water-quality data for stations in the National Water Information
# # System water-quality database.  Explanation of codes found in this file are followed by
# # the retrieved data.
#
# Number of characters in actual data: 9736982

# %% [markdown]
# Great! We have 15 chunks of text when doing that split (which feels a bit better than doing it line-by-line). Here's a breakdown of what's inside:
#     #  0:                               #  8: coll_ent_cd
#     #  1: File created...               #  9: medium_cd
#     #  2: U.S. Geological Survey        # 10: tu_id
#     #  3: The data you have...          # 11: body_part_id
#     #  4: To view additional...         # 12: remark_cd
#     #  5: Param_id      - parameter     # 13: Data for the following sites...
#     #  6: sample_start_time_datum_cd    # 14: WARNING: some spreadsheet...
#     #  7: tm_datum_rlbty_cd             # 15: Data!
#
# I've already glanced at the file in Excel and figured out how to parse all of the parameters and their descriptions, which will probably be useful later on.

# %% [markdown]
# ### Parameters
# There are about a thousand parameters, most of them are in the format of a p + 5-digit number (i.e. `p62168`). Not very descriptive, but the 6th entry of our data header has the actual descriptions for each parameter. These descriptions have a lot of information, such as the pollutant name, filtered vs unfiltered, and units of measurement.
#
# We want to later extract the pollutant and if the sample was filtered or unfiltered. For now, let's just make a dictionary to get the description for the parameters.

# %% [markdown]
# `get_params_def`: function
# * Input is `param_header`, which is a giant string with `"\n"` characters separating each line
# * Each "line" has the `p#####` parameter label and the description,

# %%
# inputs the part of the header that contains the parameter label followed by its meaning
# outputs a dictionary where the key is the label (lower case) and the value is the description
def get_params_def(param_header):
    params_def_dict = {} # Key is p#####, value is description, which contains the pollutant
    params = param_header.split("\n")
    params_pattern = re.compile("# +(\w+) +- +(.+)")

    for param in params:
        a = params_pattern.search(param)

        if a: 
            #print(first_t, a.group(1), a.group(2))
            params_def_dict[a.group(1).lower()] = a.group(2)
            #print(a.group(1) + ":", a.group(2).split(',')[-1])

    return params_def_dict

# %%
params_def_dict = get_params_def(quality_data[5])
print("Total number of parameters measured:", len(params_def_dict))
ex_param_dict = list(params_def_dict.keys())[len(params_def_dict.keys())//2]
print("Example:\n\tkey   = {}\n\tvalue = {}".format(ex_param_dict, params_def_dict[ex_param_dict]))
# Out:
# Total number of parameters measured: 1046
# Example:
# 	key   = p62168
# 	value = Fipronil sulfone, water, filtered, recoverable, micrograms per liter

# %%
needed_params = ["site_no", "sample_dt", "sample_tm"]
data_params = [param for param in params_def_dict if param[0] == "p"]

# %%
data_to_use = pd.read_csv(pd.compat.StringIO(quality_data[15]), sep='\t', low_memory=False, header=0, skiprows=[1])
# I find this a bit concerning...: https://stackoverflow.com/questions/24251219/pandas-read-csv-low-memory-and-dtype-options
# I'd want to specify type, but it seems like there's a lot of strings within supposedly numerical columns...
print(data_to_use.shape)
display(data_to_use.head(2))
# Out:
# (7763, 1046)
#   agency_cd          site_no   sample_dt sample_tm sample_end_dt  \
# 0      USGS  332031118504001  2000-10-24     14:30           NaN
# 1      USGS  333420118060501  2000-11-09     09:30           NaN
#
#   sample_end_tm sample_start_time_datum_cd tm_datum_rlbty_cd coll_ent_cd  \
# 0           NaN                        PDT                 T    USGS-WRD
# 1           NaN                        PST                 T    USGS-WRD
#
#   medium_cd   ...    p99856  p99871  p99931  p99947  p99958  p99959  p99963  \
# 0        WG   ...       NaN     0.0     NaN     NaN     NaN     NaN     NaN
# 1        WG   ...       NaN     0.0     NaN     NaN     NaN     NaN     NaN
#
#    p99972  p99994  p99995
# 0     NaN     NaN     NaN
# 1     NaN     NaN     NaN
#
# [2 rows x 1046 columns]

# %%
data_to_use_numbers = data_to_use[data_params]
data_to_use_numbers.head()
# Out:
#    p00003  p00004  p00005  p00008  p00009  p00010  p00011  p00020  p00021  \
# 0     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 1     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 2     NaN     NaN     NaN     NaN     NaN    18.5     NaN     NaN     NaN
# 3     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
# 4     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN     NaN
#
#   p00025  ...    p99856  p99871  p99931  p99947 p99958  p99959 p99963  p99972  \
# 0    NaN  ...       NaN     0.0     NaN     NaN    NaN     NaN    NaN     NaN
# 1    NaN  ...       NaN     0.0     NaN     NaN    NaN     NaN    NaN     NaN
# 2    NaN  ...       NaN     0.0     NaN     NaN    NaN     NaN    NaN   973.0
# 3    NaN  ...       NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
# 4    NaN  ...       NaN     NaN     NaN     NaN    NaN     NaN    NaN     NaN
#
#    p99994 p99995
# 0     NaN    NaN
# 1     NaN    NaN
# 2    90.7   99.8
# 3     NaN    NaN
# 4     NaN    NaN
#
# [5 rows x 1034 columns]

# %%
data_to_use_numbers = data_to_use_numbers.replace("[<> A-Za-z]", "", regex=True)
data_to_use_numbers = data_to_use_numbers.replace(" ", "", regex=True)
data_to_use_numbers = data_to_use_numbers.replace(r'^$', np.nan, regex=True)

# %%
data_to_use_numbers = data_to_use_numbers.astype(np.float64)

# %%
#total_data = pd.concat([data_to_use[needed_params], data_to_use_numbers], axis=1)

# %%
#total_data.head()

# %% [markdown]
# ## Splitting params into filtered and unfiltered
# * unfiltered = grab the ground water as is - you have extra sediment somehow
# * filtered = you filter out the ground water
# * do analysis with filtered and unfiltered, but DON'T MIX
# * higher pollution for unfiltered properties

# %% [markdown]
# #### Note
# There's some descrepencies in these parameters. We'll deal with this later.

# %%
filtered_params_1 = {}
unfiltered_params_1 = {}
for param in params_def_dict.items():
    components = param[1].split(", ")
    component = components[0].lower()
    if "filtered" in components:
        if component not in filtered_params_1:
            filtered_params_1[component] = []
        filtered_params_1[component].append(param[0])
    elif "unfiltered" in components:
        if component not in unfiltered_params_1:
            unfiltered_params_1[component] = []
        unfiltered_params_1[component].append(param[0])
        
filtered_params_2 = {}
unfiltered_params_2 = {}
for param in params_def_dict.items():
    components = param[1].split(", ")
    component = components[0].lower()
    if "unfiltered" not in components: #"filtered" in components:
        if component not in filtered_params_2:
            filtered_params_2[component] = []
        filtered_params_2[component].append(param[0])
    elif "filtered" not in components: #"unfiltered" in components:
        if component not in unfiltered_params_2:
            unfiltered_params_2[component] = []
        unfiltered_params_2[component].append(param[0])

# %%
print("For first method:")
print(len(set(filtered_params_1).intersection(set(unfiltered_params_1))))
print(len(filtered_params_1))
print(len(unfiltered_params_1))

print("For second method:")
print(len(set(filtered_params_2).intersection(set(unfiltered_params_2))))
print(len(filtered_params_2))
print(len(unfiltered_params_2))

print(len(set(filtered_params_2).difference(filtered_params_1)))
print(len(set(unfiltered_params_2).difference(unfiltered_params_1)))
print(518-197)
# Out:
# For first method:
# 57
# 197
# 360
# For second method:
# 127
# 518
# 360
# 321
# 0
# 321

# %%
# This is writing the params into a file
#unfiltered_file = open("Unfiltered_params.txt", "w")
#filtered_file = open("Filtered_params.txt", "w")
#
#for param in unfiltered_params.items():
#    formatSTR = param[0] + "\t" + "\t".join(param[1]) + "\r\n"
#    unfiltered_file.write(formatSTR.lower())
#unfiltered_file.close()
#for param in filtered_params.items():
#    formatSTR = param[0] + "\t" + "\t".join(param[1]) + "\r\n"
#    filtered_file.write(formatSTR.lower())
#filtered_file.close()

# %% [markdown]
# ## Next Step: Getting the pollutants

# %%
pollutant_file = pd.ExcelFile("Thresholds_hh_USGScompatible.xlsx")
convert_to_str = {name:str for name in pd.read_excel("Thresholds_hh_USGScompatible.xlsx").columns.values.tolist()}
pollutant_info = pollutant_file.parse(converters=convert_to_str)

# %%
pollutant_info = pollutant_info[pollutant_info["Pollutant (P = priority pollutant)"].notna()]
pollutant_info["Pollutant (P = priority pollutant)"] = pollutant_info["Pollutant (P = priority pollutant)"].str.strip()
pollutant_info["Pollutant (P = priority pollutant)"] = pollutant_info["Pollutant (P = priority pollutant)"].str.lower()
#pollutant_info["Human Health for the consumption of\xa0Water + Organism (µg/L)"] = pollutant_info["Human Health for the consumption of\xa0Water + Organism (µg/L)"].astype(str)
pollutant_info["Human Health for the consumption of\xa0Water + Organism (µg/L)"] = pollutant_info["Human Health for the consumption of\xa0Water + Organism (µg/L)"].str.replace("<", "")
pollutant_info["Human Health for the consumption of\xa0Water + Organism (µg/L)"] = pollutant_info["Human Health for the consumption of\xa0Water + Organism (µg/L)"].str.strip()
has_ranges = pollutant_info["Human Health for the consumption of\xa0Water + Organism (µg/L)"].str.contains("-")
ranges = pollutant_info[has_ranges]
ranges
pollutant_info = pollutant_info[~has_ranges]
pollutant_info["Human Health for the consumption of\xa0Water + Organism (µg/L)"] = pd.to_numeric(pollutant_info["Human Health for the consumption of\xa0Water + Organism (µg/L)"])
pollutant_info.head()
# Out:
#   Pollutant (P = priority pollutant) CAS Number  \
# 0                       acenaphthene      83329
# 1                      acrylonitrile     107131
# 2                             aldrin     309002
# 3                          alpha-hch     319846
# 4                   alpha-endosulfan     959988
#
#    Human Health for the consumption of Water + Organism (µg/L)  \
# 0                                       7.000000e+01
# 1                                       6.100000e-02
# 2                                       7.700000e-07
# 3                                       3.600000e-04
# 4                                       2.000000e+01
#
#   Human Health for the consumption of Organism Only (µg/L) Publication Year  \
# 0                                                 90                   2015
# 1                                                  7                   2015
# 2                                            7.7e-07                   2015
# 3                                            0.00039                   2015
# 4                                                30                    2015
#
#                                                Notes
# 0  The criterion for organoleptic (taste and odor...
# 1  This criterion is based on carcinogenicity of ...
# 2  This criterion is based on carcinogenicity of ...
# 3  This criterion is based on carcinogenicity of ...
# 4                                                NaN

# %%
# Where we got the columns with the same pollutant names
common_pollutants_p = []
reverse_params_def_dict = {}
pollutant_info["Pollutant (P = priority pollutant)"]=pollutant_info["Pollutant (P = priority pollutant)"].str.lower()
a = pollutant_info["Pollutant (P = priority pollutant)"]
a = a[a.notna()]
for pollutant in a:
    pollutant = pollutant
    if pollutant in filtered_params_2:
        for column in filtered_params_2[pollutant]:
            common_pollutants_p.append(column)
            reverse_params_def_dict[column] = pollutant
#reverse_params_def_dict
#common_pollutants_p

# %%
reverse_params_def_dict
# Out:
# {'p39333': 'aldrin',
#  'p34253': 'alpha-hch',
#  'p34362': 'alpha-endosulfan',
#  'p39389': 'alpha-endosulfan',
#  'p63180': 'anthracene',
#  'p01095': 'antimony',
#  'p01000': 'arsenic',
#  'p01001': 'arsenic',
#  'p01003': 'arsenic',
#  'p01005': 'barium',
#  'p01006': 'barium',
#  'p63183': 'benzo[a]pyrene',
#  'p01010': 'beryllium',
#  'p63187': 'bis(2-ethylhexyl) phthalate',
#  'p01025': 'cadmium',
#  'p01026': 'cadmium',
#  'p01028': 'cadmium',
#  'p01030': 'chromium',
#  'p01031': 'chromium',
#  'p01040': 'copper',
#  'p01041': 'copper',
#  'p01043': 'copper',
#  'p00721': 'cyanide',
#  'p39381': 'dieldrin',
#  'p39383': 'dieldrin',
#  'p63202': 'diethyl phthalate',
#  'p61590': 'endosulfan sulfate',
#  'p39393': 'endrin',
#  'p63208': 'fluoranthene',
#  'p39413': 'heptachlor',
#  'p39423': 'heptachlor epoxide',
#  'p63212': 'isophorone',
#  'p01054': 'manganese',
#  'p01056': 'manganese',
#  'p39481': "p,p'-methoxychlor",
#  'p01065': 'nickel',
#  'p01066': 'nickel',
#  'p01068': 'nickel',
#  'p00618': 'nitrate',
#  'p71851': 'nitrate',
#  'p63225': 'phenol',
#  'p39519': 'pcbs',
#  'p63227': 'pyrene',
#  'p01145': 'selenium',
#  'p01146': 'selenium',
#  'p01148': 'selenium',
#  'p70301': 'dissolved solids',
#  'p70302': 'dissolved solids',
#  'p70303': 'dissolved solids',
#  'p01057': 'thallium',
#  'p39403': 'toxaphene',
#  'p01090': 'zinc',
#  'p01091': 'zinc',
#  'p01093': 'zinc',
#  'p63163': '1,4-dichlorobenzene',
#  'p49299': '2-methyl-4,6-dinitrophenol'}

# %%
total_data = pd.concat([data_to_use[needed_params], data_to_use_numbers[common_pollutants_p]], axis=1)
#data_to_use_subset.head()

#total_data.notna().sum() # <- this is useful when looking at how many values each column has

# %%
total_data.shape
# Out:
# (7763, 59)

# %%
common_pollutants_p
# Out:
# ['p39333',
#  'p34253',
#  'p34362',
#  'p39389',
#  'p63180',
#  'p01095',
#  'p01000',
#  'p01001',
#  'p01003',
#  'p01005',
#  'p01006',
#  'p63183',
#  'p01010',
#  'p63187',
#  'p01025',
#  'p01026',
#  'p01028',
#  'p01030',
#  'p01031',
#  'p01040',
#  'p01041',
#  'p01043',
#  'p00721',
#  'p39381',
#  'p39383',
#  'p63202',
#  'p61590',
#  'p39393',
#  'p63208',
#  'p39413',
#  'p39423',
#  'p63212',
#  'p01054',
#  'p01056',
#  'p39481',
#  'p01065',
#  'p01066',
#  'p01068',
#  'p00618',
#  'p71851',
#  'p63225',
#  'p39519',
#  'p63227',
#  'p01145',
#  'p01146',
#  'p01148',
#  'p70301',
#  'p70302',
#  'p70303',
#  'p01057',
#  'p39403',
#  'p01090',
#  'p01091',
#  'p01093',
#  'p63163',
#  'p49299']

# %% [markdown]
# ### Try the CA Pollutants instead

# %%
ca_pollutant_file = pd.ExcelFile("CA_thresholds_compliation_filtered.xlsx")
ca_pollutant_info = ca_pollutant_file.parse()

# %%
ca_pollutant_info.head()
# Out:
#             Name1 Name2  Name3  Name4       Sort_Name  CAS_Number  \
# 0    Acenaphthene   NaN    NaN    NaN    Acenaphthene     83-32-9
# 1  Acenaphthylene   NaN    NaN    NaN  Acenaphthylene    208-96-8
# 2      Acetochlor   NaN    NaN    NaN      Acetochlor  34256-82-1
# 3         Acetone   NaN    NaN    NaN         acetone     67-64-1
# 4    Acetonitrile   NaN    NaN    NaN    Acetonitrile     75-05-8
#
#   Organic_Inorganic  CA_Prim_MCL  CA_Prim_MCL_2 CA_Prim_MCL_unit  \
# 0           Organic          NaN            NaN              NaN
# 1           Organic          NaN            NaN              NaN
# 2           Organic          NaN            NaN              NaN
# 3           Organic          NaN            NaN              NaN
# 4           Organic          NaN            NaN              NaN
#
#           ...          CA_BayEst_Health_unit  CA_BayEst_Health_date  \
# 0         ...                            NaN             2000-05-18
# 1         ...                            NaN                    NaT
# 2         ...                            NaN                    NaT
# 3         ...                            NaN                    NaT
# 4         ...                            NaN                    NaT
#
#    NAWQC_Health_WF NAWQC_Health_WF_2 NAWQC_Health_WF_unit  \
# 0             70.0               NaN                  NaN
# 1              NaN               NaN                  NaN
# 2              NaN               NaN                  NaN
# 3              NaN               NaN                  NaN
# 4              NaN               NaN                  NaN
#
#    NAWQC_Health_WF_date  NAWQC_Health_F NAWQC_Health_F_2 NAWQC_Health_F_unit  \
# 0            2015-06-29            90.0              NaN                 NaN
# 1                   NaT             NaN              NaN                 NaN
# 2                   NaT             NaN              NaN                 NaN
# 3                   NaT             NaN              NaN                 NaN
# 4                   NaT             NaN              NaN                 NaN
#
#    NAWQC_Health_F_date
# 0           2015-06-29
# 1                  NaT
# 2                  NaT
# 3                  NaT
# 4                  NaT
#
# [5 rows x 95 columns]

# %%
ca_pollutant_info.iloc[:, :5] = ca_pollutant_info.iloc[:, :5].replace(to_replace=np.nan, value="")
names = ca_pollutant_info["Name1"].copy(deep = True)
names = names.str.lower()
names.head()
ca_pollutant_info.head()
# Out:
#             Name1 Name2 Name3 Name4       Sort_Name  CAS_Number  \
# 0    Acenaphthene                      Acenaphthene     83-32-9
# 1  Acenaphthylene                    Acenaphthylene    208-96-8
# 2      Acetochlor                        Acetochlor  34256-82-1
# 3         Acetone                           acetone     67-64-1
# 4    Acetonitrile                      Acetonitrile     75-05-8
#
#   Organic_Inorganic  CA_Prim_MCL  CA_Prim_MCL_2 CA_Prim_MCL_unit  \
# 0           Organic          NaN            NaN              NaN
# 1           Organic          NaN            NaN              NaN
# 2           Organic          NaN            NaN              NaN
# 3           Organic          NaN            NaN              NaN
# 4           Organic          NaN            NaN              NaN
#
#           ...          CA_BayEst_Health_unit  CA_BayEst_Health_date  \
# 0         ...                            NaN             2000-05-18
# 1         ...                            NaN                    NaT
# 2         ...                            NaN                    NaT
# 3         ...                            NaN                    NaT
# 4         ...                            NaN                    NaT
#
#    NAWQC_Health_WF NAWQC_Health_WF_2 NAWQC_Health_WF_unit  \
# 0             70.0               NaN                  NaN
# 1              NaN               NaN                  NaN
# 2              NaN               NaN                  NaN
# 3              NaN               NaN                  NaN
# 4              NaN               NaN                  NaN
#
#    NAWQC_Health_WF_date  NAWQC_Health_F NAWQC_Health_F_2 NAWQC_Health_F_unit  \
# 0            2015-06-29            90.0              NaN                 NaN
# 1                   NaT             NaN              NaN                 NaN
# 2                   NaT             NaN              NaN                 NaN
# 3                   NaT             NaN              NaN                 NaN
# 4                   NaT             NaN              NaN                 NaN
#
#    NAWQC_Health_F_date
# 0           2015-06-29
# 1                  NaT
# 2                  NaT
# 3                  NaT
# 4                  NaT
#
# [5 rows x 95 columns]

# %%
filtered_params_2
# Out:
# {'agency code': ['agency_cd'],
#  'station number': ['site_no'],
#  'begin date': ['sample_dt'],
#  'begin time': ['sample_tm'],
#  'end date': ['sample_end_dt'],
#  'end time': ['sample_end_tm'],
#  'time datum': ['sample_start_time_datum_cd'],
#  'time datum reliability code': ['tm_datum_rlbty_cd'],
#  'agency collecting sample code': ['coll_ent_cd'],
#  'medium code': ['medium_cd'],
#  'taxonomic unit code': ['tu_id'],
#  'body part code': ['body_part_id'],
#  'sampling depth': ['p00003', 'p00098'],
#  'stream width': ['p00004'],
#  'location in cross section': ['p00005', 'p00009'],
#  'sample accounting number': ['p00008'],
#  'temperature': ['p00010', 'p00011', 'p00020', 'p00021'],
#  'barometric pressure': ['p00025'],
#  'agency analyzing sample': ['p00028'],
#  'project number': ['p00029'],
#  'cloud cover': ['p00032'],
#  'flow rate of well': ['p00058'],
#  'flow rate': ['p00059'],
#  'discharge': ['p00060', 'p00061', 'p30208', 'p30209'],
#  'gage height': ['p00065', 'p30207'],
#  'color': ['p00080'],
#  'odor at room temperature': ['p00085'],
#  'oxidation reduction potential': ['p00090'],
#  'carbonate': ['p00452', 'p29807', 'p63788'],
#  'bicarbonate': ['p00453', 'p29804', 'p63786'],
#  'dissolved solids dried at 105 degrees celsius': ['p00515'],
#  'loss on ignition of dissolved solids': ['p00520'],
#  'biomass': ['p00572', 'p00573', 'p49954'],
#  'total nitrogen [nitrate + nitrite + ammonia + organic-n]': ['p00602',
#   'p62854'],
#  'organic nitrogen': ['p00607'],
#  'ammonia (nh3 + nh4+)': ['p00608', 'p71846'],
#  'nitrite': ['p00613', 'p71856'],
#  'nitrate': ['p00618', 'p71851'],
#  'ammonia plus organic nitrogen': ['p00623', 'p00624'],
#  'nitrate plus nitrite': ['p00631'],
#  'orthophosphate': ['p00660', 'p00671'],
#  'phosphorus': ['p00666'],
#  'organic carbon': ['p00681', 'p00689', 'p30243'],
#  'cyanide': ['p00721'],
#  'sulfide': ['p00746', 'p99118'],
#  'hardness': ['p00900'],
#  'noncarbonate hardness': ['p00904', 'p00905', 'p95902'],
#  'calcium': ['p00915'],
#  'magnesium': ['p00925'],
#  'sodium': ['p00930'],
#  'sodium adsorption ratio (sar)': ['p00931'],
#  'sodium fraction of cations': ['p00932'],
#  'sodium plus potassium': ['p00933'],
#  'potassium': ['p00935'],
#  'chloride': ['p00940'],
#  'sulfate': ['p00945'],
#  'fluoride': ['p00950', 'p91002'],
#  'silica': ['p00955'],
#  'arsenic': ['p01000', 'p01001', 'p01003'],
#  'barium': ['p01005', 'p01006'],
#  'beryllium': ['p01010'],
#  'boron': ['p01020'],
#  'cadmium': ['p01025', 'p01026', 'p01028'],
#  'chromium': ['p01030', 'p01031'],
#  'chromium(vi)': ['p01032'],
#  'cobalt': ['p01035', 'p01036'],
#  'copper': ['p01040', 'p01041', 'p01043'],
#  'iron': ['p01044', 'p01046', 'p01170'],
#  'iron(ii)': ['p01047'],
#  'iron(ii) plus iron(iii)': ['p01048'],
#  'lead': ['p01049', 'p01050', 'p01052'],
#  'manganese': ['p01054', 'p01056'],
#  'thallium': ['p01057'],
#  'molybdenum': ['p01060'],
#  'nickel': ['p01065', 'p01066', 'p01068'],
#  'silver': ['p01075', 'p01076'],
#  'strontium': ['p01080'],
#  'vanadium': ['p01085'],
#  'zinc': ['p01090', 'p01091', 'p01093'],
#  'antimony': ['p01095'],
#  'aluminum': ['p01106'],
#  'lithium': ['p01130'],
#  'selenium': ['p01145', 'p01146', 'p01148'],
#  'tungsten': ['p01155'],
#  'terbuthylazine': ['p04022'],
#  'propachlor': ['p04024'],
#  'hexazinone': ['p04025'],
#  'butylate': ['p04028'],
#  'bromacil': ['p04029', 'p63189'],
#  'cycloate': ['p04031'],
#  'terbacil': ['p04032', 'p82665'],
#  'diphenamid': ['p04033'],
#  'simazine': ['p04035'],
#  'prometryn': ['p04036'],
#  'prometon': ['p04037', 'p63226'],
#  '2-chloro-6-ethylamino-4-amino-s-triazine': ['p04038'],
#  '2-chloro-4-isopropylamino-6-amino-s-triazine': ['p04040'],
#  'cyanazine': ['p04041'],
#  'fonofos': ['p04095'],
#  'tritium in water molecules': ['p07012'],
#  'tritium in water molecules counting error': ['p07013'],
#  'radium-226': ['p09503', 'p09511'],
#  'uranium-238': ['p22603'],
#  'uranium-234': ['p22610'],
#  'uranium-235': ['p22620'],
#  'uranium (natural)': ['p22703'],
#  'alkalinity': ['p29801', 'p29802', 'p39036', 'p39086'],
#  'depth to water level': ['p30210', 'p72019'],
#  'inorganic carbon': ['p30241'],
#  'total coliforms': ['p31501', 'p31503', 'p50569', 'p90900'],
#  'fecal coliforms': ['p31616', 'p31625'],
#  'fecal streptococci': ['p31673', 'p31679'],
#  'sample volume': ['p32002',
#   'p99840',
#   'p99848',
#   'p99855',
#   'p99856',
#   'p99947',
#   'p99963',
#   'p99972'],
#  'alpha-hch': ['p34253'],
#  'alpha-endosulfan': ['p34362', 'p39389'],
#  "p,p'-dde": ['p34653', 'p39368'],
#  'dicamba': ['p38442'],
#  'dicrotophos': ['p38454'],
#  'linuron': ['p38478', 'p82666'],
#  'mcpa': ['p38482'],
#  'mcpb': ['p38487'],
#  'methiocarb': ['p38501'],
#  'propoxur': ['p38538'],
#  'siduron': ['p38548'],
#  'bentazon': ['p38711'],
#  '2,4-db': ['p38746'],
#  'dichlorvos': ['p38775'],
#  'fluometuron': ['p38811'],
#  'oxamyl': ['p38866'],
#  'chlorpyrifos': ['p38933', 'p63195'],
#  'polychlorinated naphthalenes': ['p39251'],
#  'aldrin': ['p39333'],
#  'lindane': ['p39341', 'p39343'],
#  'chlordane (technical)': ['p39351'],
#  "p,p'-ddd": ['p39363'],
#  "p,p'-ddt": ['p39373'],
#  'dieldrin': ['p39381', 'p39383'],
#  'endrin': ['p39393'],
#  'toxaphene': ['p39403'],
#  'heptachlor': ['p39413'],
#  'metolachlor': ['p39415', 'p63218'],
#  'heptachlor epoxide': ['p39423'],
#  "p,p'-methoxychlor": ['p39481'],
#  'pcbs': ['p39519'],
#  'malathion': ['p39532'],
#  'parathion': ['p39542'],
#  'diazinon': ['p39572', 'p63198'],
#  'atrazine': ['p39632', 'p63182'],
#  '2,4-d': ['p39732'],
#  '2,4,5-t': ['p39742', 'p99958'],
#  'mirex': ['p39758'],
#  'silvex': ['p39762'],
#  'alachlor': ['p46342'],
#  'precipitation': ['p46529'],
#  'triclopyr': ['p49235'],
#  'propham': ['p49236'],
#  'acetochlor': ['p49260'],
#  'picloram': ['p49291'],
#  'oryzalin': ['p49292'],
#  'norflurazon': ['p49293'],
#  'neburon': ['p49294'],
#  '1-naphthol': ['p49295'],
#  'methomyl': ['p49296'],
#  'fenuron': ['p49297'],
#  '2-methyl-4,6-dinitrophenol': ['p49299'],
#  'diuron': ['p49300'],
#  'dinoseb': ['p49301'],
#  'dichlorprop': ['p49302'],
#  'dichlobenil': ['p49303'],
#  'dcpa monoacid': ['p49304'],
#  'clopyralid': ['p49305'],
#  'chlorothalonil': ['p49306'],
#  '3-hydroxy carbofuran': ['p49308'],
#  'carbofuran': ['p49309', 'p82674'],
#  'carbaryl': ['p49310', 'p82680'],
#  'bromoxynil': ['p49311'],
#  'aldicarb': ['p49312'],
#  'aldicarb sulfone': ['p49313'],
#  'aldicarb sulfoxide': ['p49314'],
#  'acifluorfen': ['p49315'],
#  'delta sulfur-34/sulfur-32 of sulfate': ['p49932'],
#  'carbon-14': ['p49933'],
#  'carbon-14 counting error': ['p49934'],
#  'site visit purpose': ['p50280'],
#  'bendiocarb': ['p50299'],
#  'benomyl': ['p50300'],
#  'caffeine': ['p50305'],
#  'chlorimuron-ethyl': ['p50306'],
#  'sulfometuron-methyl': ['p50337'],
#  '2-hydroxy-4-isopropylamino-6-ethylamino-s-triazine': ['p50355'],
#  'imazaquin': ['p50356'],
#  'metalaxyl': ['p50359', 'p61596'],
#  'nicosulfuron': ['p50364'],
#  'imazethapyr': ['p50407'],
#  'escherichia coli': ['p50468', 'p90901', 'p90902'],
#  '2,4-d methyl ester': ['p50470'],
#  'propiconazole': ['p50471'],
#  'absorbance': ['p50624', 'p61726'],
#  'radium-224': ['p50833'],
#  'helium': ['p51188'],
#  'hydrogen': ['p51189'],
#  'argon': ['p51190', 'p85563'],
#  'oxygen': ['p51191'],
#  'carbon dioxide': ['p51192'],
#  'dinitrogen': ['p51193'],
#  'carbon monoxide': ['p51194'],
#  'propene': ['p51195'],
#  'c6 and higher-molecular-weight hydrocarbons': ['p51196'],
#  'phytoplankton': ['p60050'],
#  'tribenuron-methyl': ['p61159'],
#  'chloramben methyl ester': ['p61188'],
#  'cyfluthrin': ['p61585'],
#  'cypermethrin': ['p61586'],
#  'endosulfan sulfate': ['p61590'],
#  'fenamiphos': ['p61591'],
#  'iprodione': ['p61593'],
#  'isofenphos': ['p61594'],
#  'lambda-cyhalothrin': ['p61595'],
#  'methidathion': ['p61598'],
#  'myclobutanil': ['p61599'],
#  'oxyfluorfen': ['p61600'],
#  'phosmet': ['p61601'],
#  'tefluthrin': ['p61606'],
#  'tribufos': ['p61610'],
#  "2-chloro-2',6'-diethylacetanilide": ['p61618'],
#  '2-ethyl-6-methylaniline': ['p61620'],
#  '3,4-dichloroaniline': ['p61625'],
#  '3,5-dichloroaniline': ['p61627'],
#  '4-chloro-2-methylphenol': ['p61633'],
#  'azinphos-methyl oxygen analog': ['p61635'],
#  'chlorpyrifos oxygen analog': ['p61636'],
#  'diazoxon': ['p61638'],
#  'disulfoton sulfone': ['p61640'],
#  'ethion monoxon': ['p61644'],
#  'fenamiphos sulfone': ['p61645'],
#  'fenamiphos sulfoxide': ['p61646'],
#  'malaoxon': ['p61652'],
#  'methyl paraoxon': ['p61664'],
#  'phorate oxygen analog': ['p61666'],
#  'phosmet oxygen analog': ['p61668'],
#  'terbufos oxygen analog sulfone': ['p61674'],
#  "n-(4-chlorophenyl)-n'-methylurea": ['p61692'],
#  'bensulfuron-methyl': ['p61693'],
#  'flumetsulam': ['p61694'],
#  'imidacloprid': ['p61695'],
#  'metsulfuron-methyl': ['p61697'],
#  'acetaminophen': ['p62000'],
#  'codeine': ['p62003'],
#  'dehydronifedipine': ['p62004'],
#  'cotinine': ['p62005'],
#  'diltiazem': ['p62008'],
#  'albuterol': ['p62020'],
#  'sulfamethoxazole': ['p62021'],
#  'trimethoprim': ['p62023'],
#  'warfarin': ['p62024'],
#  '1,7-dimethylxanthine': ['p62030'],
#  'fipronil': ['p62166'],
#  'fipronil sulfide': ['p62167'],
#  'fipronil sulfone': ['p62168'],
#  'desulfinylfipronil amide': ['p62169'],
#  'desulfinylfipronil': ['p62170'],
#  'pheophytin a': ['p62360'],
#  'arsenite': ['p62452'],
#  'carbon [inorganic plus organic]': ['p62463'],
#  'gross alpha radioactivity': ['p62636', 'p62639'],
#  'gross beta radioactivity': ['p62642', 'p62645'],
#  'delta boron-11/boron-10': ['p62648'],
#  'carbamazepine': ['p62793'],
#  'diphenhydramine': ['p62796'],
#  'thiabendazole': ['p62801'],
#  'delta oxygen-18/oxygen-16 of nitrate': ['p63041'],
#  'specific uv absorbance': ['p63162'],
#  '1,4-dichlorobenzene': ['p63163'],
#  '1-methylnaphthalene': ['p63165'],
#  '2,6-dimethylnaphthalene': ['p63167'],
#  '2-methylnaphthalene': ['p63168'],
#  '3-beta-coprostanol': ['p63170'],
#  '3-methyl-1h-indole': ['p63171'],
#  '3-tert-butyl-4-hydroxyanisole': ['p63172'],
#  '4-cumylphenol': ['p63173'],
#  '4-n-octylphenol': ['p63174'],
#  '4-nonylphenol (sum of all isomers)': ['p63175'],
#  '4-tert-octylphenol': ['p63176'],
#  'acetophenone': ['p63178'],
#  'acetyl hexamethyl tetrahydro naphthalene': ['p63179'],
#  'anthracene': ['p63180'],
#  '9,10-anthraquinone': ['p63181'],
#  'benzo[a]pyrene': ['p63183'],
#  'benzophenone': ['p63184'],
#  'beta-sitosterol': ['p63185'],
#  'beta-stigmastanol': ['p63186'],
#  'bis(2-ethylhexyl) phthalate': ['p63187'],
#  'bisphenol a': ['p63188'],
#  'camphor': ['p63192'],
#  'carbazole': ['p63194'],
#  'cholesterol': ['p63196'],
#  '4-nonylphenol diethoxylate (sum of all isomers)': ['p63200'],
#  '4-tert-octylphenol diethoxylate': ['p63201'],
#  'diethyl phthalate': ['p63202'],
#  'd-limonene': ['p63203'],
#  '4-tert-octylphenol monoethoxylate': ['p63206'],
#  'fluoranthene': ['p63208'],
#  'hexahydrohexamethyl cyclopentabenzopyran': ['p63209'],
#  'indole': ['p63210'],
#  'isoborneol': ['p63211'],
#  'isophorone': ['p63212'],
#  'isopropylbenzene': ['p63213'],
#  'isoquinoline': ['p63214'],
#  'menthol': ['p63215'],
#  'n,n-diethyl-m-toluamide (deet)': ['p63219'],
#  'naphthalene': ['p63220'],
#  '4-nonylphenol monoethoxylate (sum of all isomers)': ['p63221'],
#  'p-cresol': ['p63222'],
#  'phenanthrene': ['p63224'],
#  'phenol': ['p63225'],
#  'pyrene': ['p63227'],
#  'tris(2-butoxyethyl) phosphate': ['p63229'],
#  'tris(2-chloroethyl) phosphate': ['p63230'],
#  'tributyl phosphate': ['p63231'],
#  'triclosan': ['p63232'],
#  'triphenyl phosphate': ['p63234'],
#  'tris(dichloroisopropyl) phosphate': ['p63235'],
#  'hydrophobic acid fraction of dissolved organic carbon': ['p63737'],
#  'hydrophilic acid fraction of dissolved organic carbon': ['p63738'],
#  'transphilic organic acid fraction of dissolved organic carbon': ['p63739'],
#  'specific uv absorbance at 254 nm of hydrophobic acid fraction of doc': ['p63742'],
#  'specific uv absorbance at 254 nm of hydrophilic acid fraction of doc': ['p63743'],
#  'specific uv absorbance at 254 nm of transphilic organic acid fraction of doc': ['p63744'],
#  'perchlorate': ['p63790'],
#  'delta carbon-13/carbon-12 of methane': ['p65241'],
#  'delta carbon-13/carbon-12 of ethane': ['p65242'],
#  'delta hydrogen-2/hydrogen-1 of methane': ['p65245'],
#  '2,4-d plus 2,4-d methyl ester': ['p66496'],
#  'methane': ['p68823', 'p68831'],
#  'ethane': ['p68824', 'p68832'],
#  'ethene': ['p68825'],
#  'propane': ['p68826', 'p68834'],
#  '2-methylpropane (isobutane)': ['p68827'],
#  'n-butane': ['p68828'],
#  '2-methylbutane (isopentane)': ['p68829'],
#  'n-pentane': ['p68830'],
#  'dissolved solids dried at 180 degrees celsius': ['p70300'],
#  'dissolved solids': ['p70301', 'p70302', 'p70303'],
#  'suspended sediment': ['p70331',
#   'p70332',
#   'p70333',
#   'p70334',
#   'p70337',
#   'p70338',
#   'p70339',
#   'p70340',
#   'p70341',
#   'p70342',
#   'p70343',
#   'p70344',
#   'p70345',
#   'p70346',
#   'p70347'],
#  'biomass to chlorophyll ratio': ['p70950'],
#  'chlorophyll a': ['p70953', 'p70957'],
#  'chlorophyll b': ['p70958'],
#  'hydroxide': ['p71834'],
#  'iodide': ['p71865'],
#  'bromide': ['p71870'],
#  'mercury': ['p71890', 'p71895', 'p71921'],
#  'sample purpose': ['p71999'],
#  'altitude of land surface': ['p72000'],
#  'depth of hole': ['p72001'],
#  'pump or flow period prior to sampling': ['p72004'],
#  'sample source': ['p72005'],
#  'sampling condition': ['p72006'],
#  'depth of well': ['p72008'],
#  'depth to top of sample interval': ['p72015'],
#  'depth to bottom of sample interval': ['p72016'],
#  'elevation of sample': ['p72106'],
#  'strontium-87/strontium-86 ratio': ['p75978'],
#  'cis-propiconazole': ['p79846'],
#  'trans-propiconazole': ['p79847'],
#  'suspended sediment concentration': ['p80154'],
#  'suspended sediment discharge': ['p80155'],
#  'drainage area': ['p81024'],
#  'filter pore size': ['p81352'],
#  'radium-228': ['p81366'],
#  "p,p'-ethyl-ddd": ['p81886'],
#  'depth to bottom at sample location': ['p81903'],
#  'mean depth of lake': ['p82015'],
#  'potassium-40': ['p82068'],
#  'ethion': ['p82346'],
#  'sampling method': ['p82398'],
#  'metribuzin': ['p82630'],
#  '2,6-diethylaniline': ['p82660'],
#  'trifluralin': ['p82661'],
#  'dimethoate': ['p82662'],
#  'ethalfluralin': ['p82663'],
#  'phorate': ['p82664'],
#  'methyl parathion': ['p82667'],
#  'eptc': ['p82668'],
#  'pebulate': ['p82669'],
#  'tebuthiuron': ['p82670'],
#  'molinate': ['p82671'],
#  'ethoprop': ['p82672'],
#  'benfluralin': ['p82673'],
#  'terbufos': ['p82675'],
#  'propyzamide': ['p82676'],
#  'disulfoton': ['p82677'],
#  'triallate': ['p82678'],
#  'propanil': ['p82679'],
#  'thiobencarb': ['p82681'],
#  'dcpa': ['p82682'],
#  'pendimethalin': ['p82683'],
#  'napropamide': ['p82684'],
#  'propargite': ['p82685'],
#  'azinphos-methyl': ['p82686'],
#  'cis-permethrin': ['p82687'],
#  'delta nitrogen-15/nitrogen-14 of nitrate': ['p82690'],
#  'delta nitrogen-15/nitrogen-14 of ammonia': ['p82691'],
#  'delta chromium-53/chromium-52': ['p82701'],
#  'depth to bottom from water surface': ['p82903'],
#  'sampler type': ['p84164'],
#  'helium-4': ['p85561'],
#  'krypton': ['p85565'],
#  'xenon': ['p85567'],
#  'barban': ['p90640'],
#  'decafluorobiphenyl': ['p90737'],
#  'fluoranthene-d10': ['p90738'],
#  'enterococci': ['p90909', 'p99601'],
#  'diazinon-d10': ['p91063', 'p99994'],
#  'alpha-hch-d6': ['p91065', 'p99995'],
#  'sample weight': ['p91100'],
#  'bisphenol a-d14': ['p91749'],
#  'conversion factor': ['p95100'],
#  'total cell count': ['p95200'],
#  'chlamydomonadaceae      (3) usgs,acl-74': ['p96012'],
#  'carteria                (4) usgs,acl-74': ['p96013'],
#  'chlamydomonas           (4) usgs,acl-74': ['p96014'],
#  'chlorogonium            (4) usgs,acl-74': ['p96015'],
#  'lobomonas               (4) usgs,acl-74': ['p96016'],
#  'phacotus                (4) usgs,acl-74': ['p96028'],
#  'pteromonas              (4) usgs,acl-74': ['p96029'],
#  'eudorina                (4) usgs,acl-74': ['p96036'],
#  'gloeocystis             (4) usgs,acl-74': ['p96063'],
#  'elakatothrix            (4) usgs,acl-74': ['p96086'],
#  'uronema                 (4) usgs,acl-74': ['p96101'],
#  'microspora              (4) usgs,acl-74': ['p96104'],
#  'stigeoclonium           (4) usgs,acl-74': ['p96117'],
#  'coleochaete             (4) usgs,acl-74': ['p96123'],
#  'cladophora              (4) usgs,acl-74': ['p96140'],
#  'oedogonium              (4) usgs,acl-74': ['p96151'],
#  'schroederia             (4) usgs,acl-74': ['p96190'],
#  'pediastrum              (4) usgs,acl-74': ['p96197'],
#  'coelastrum              (4) usgs,acl-74': ['p96200'],
#  'ankistrodesmus          (4) usgs,acl-74': ['p96202'],
#  'chlorella               (4) usgs,acl-74': ['p96205'],
#  'closteriopsis           (4) usgs,acl-74': ['p96207'],
#  'dictyosphaerium         (4) usgs,acl-74': ['p96209'],
#  'franceia                (4) usgs,acl-74 -96203': ['p96213'],
#  'kirchneriella           (4) usgs,acl-74': ['p96215'],
#  'nephrocytium            (4) usgs,acl-74': ['p96217'],
#  'oocystis                (4) usgs,acl-74': ['p96218'],
#  'quadrigula              (4) usgs,acl-74': ['p96223'],
#  'selenastrum             (4) usgs,acl-74': ['p96225'],
#  'tetraedron              (4) usgs,acl-74': ['p96226'],
#  'chodatella              (4) usgs,acl-74': ['p96230'],
#  'scenedesmaceae          (3) usgs,acl-74': ['p96237'],
#  'actinastrum             (4) usgs,acl-74': ['p96238'],
#  'crucigenia              (4) usgs,acl-74': ['p96240'],
#  'scenedesmus             (4) usgs,acl-74': ['p96243'],
#  'tetrastrum              (4) usgs,acl-74': ['p96245'],
#  'golenkinia              (4) usgs,acl-74': ['p96252'],
#  'micractinium            (4) usgs,acl-74': ['p96254'],
#  'closterium              (4) usgs,acl-74': ['p96312'],
#  'cosmarium               (4) usgs,acl-74': ['p96313'],
#  'staurastrum             (4) usgs,acl-74': ['p96327'],
#  'euglena                 (4) usgs,acl-74': ['p96387'],
#  'phacus                  (4) usgs,acl-74': ['p96390'],
#  'trachelomonas           (4) usgs,acl-74': ['p96392'],
#  'chroomonas              (4) usgs,acl-74': ['p96413'],
#  'cryptomonas             (4) usgs,acl-74': ['p96416'],
#  'cryptomonas             (4) usgs,acl-74 -96416': ['p96430'],
#  'glenodinium             (4) usgs,acl-74': ['p96484'],
#  'mallomonas              (4) usgs,acl-74': ['p96595'],
#  'ochromonas              (4) usgs,acl-74': ['p96608'],
#  'uroglenopsis            (4) usgs,acl-74': ['p96610'],
#  'cyclotella              (4) usgs,acl-74': ['p96706'],
#  'melosira                (4) usgs,acl-74': ['p96707'],
#  'stephanodiscus          (4) usgs,acl-74': ['p96708'],
#  'tabellaria              (4) usgs,acl-74': ['p96750'],
#  'meridion                (4) usgs,acl-74': ['p96756'],
#  'diatoma                 (4) usgs,acl-74': ['p96759'],
#  'fragilaria              (4) usgs,acl-74': ['p96764'],
#  'synedra                 (4) usgs,acl-74': ['p96765'],
#  'achnanthes              (4) usgs,acl-74': ['p96777'],
#  'cocconeis               (4) usgs,acl-74': ['p96778'],
#  'rhoicosphenia           (4) usgs,acl-75': ['p96779'],
#  'diploneis               (4) usgs,acl-74': ['p96787'],
#  'navicula                (4) usgs,acl-74': ['p96791'],
#  'gomphonema              (4) usgs,acl-74': ['p96802'],
#  'amphora                 (4) usgs,acl-74': ['p96805'],
#  'cymbella                (4) usgs,acl-74': ['p96806'],
#  'epithemia               (4) usgs,acl-74': ['p96807'],
#  'denticula               (4) usgs,acl-74': ['p96810'],
#  'hantzschia              (4) usgs,acl-74': ['p96811'],
#  'nitzschia               (4) usgs,acl-74': ['p96812'],
#  'surirella               (4) usgs,acl-74': ['p96817'],
#  'anacystis               (4) menegh,1837 -98066': ['p98082'],
#  'agmenellum              (4) breb. ,1839': ['p98090'],
#  'coccochloris            (4) spreng,1827': ['p98093'],
#  "lyngbya                 (4) agard' ,1824": ['p98131'],
#  'oscillatoria            (4) vaucher,1803': ['p98136'],
#  'phormidium              (4)  keutz,1843': ['p98142'],
#  'anabaena                (4) usgs,acl-74': ['p98165'],
#  'anabaenopsis            (4) usgs,acl-74': ['p98166'],
#  'aphanizomenon           (4) usgs,acl-74': ['p98167'],
#  'cylindrospermum         (4) usgs,acl-74': ['p98169'],
#  'plectonema              (4) usgs,acl-74': ['p98182'],
#  'inorganic arsenic(iii)': ['p99034'],
#  'type of replicate': ['p99105'],
#  'type of quality assurance data associated with sample': ['p99111'],
#  'topical quality-control data purpose': ['p99112'],
#  'hydrochloric acid nwis lot number': ['p99157', 'p99158'],
#  'nitric acid nwis lot number': ['p99159'],
#  'conductance standard nwis lot number': ['p99161',
#   'p99162',
#   'p99163',
#   'p99164',
#   'p99165',
#   'p99166',
#   'p99167',
#   'p99177'],
#  'ph 10 buffer solution': ['p99171'],
#  'ph 4 buffer solution': ['p99172'],
#  'ph 7 buffer solution': ['p99173'],
#  'sulfuric acid titrant nwis lot number': ['p99174'],
#  'lot number': ['p99200', 'p99204'],
#  'nwis lot number': ['p99206'],
#  'coliphage': ['p99332', 'p99335'],
#  'set number': ['p99630',
#   'p99631',
#   'p99660',
#   'p99750',
#   'p99818',
#   'p99820',
#   'p99827',
#   'p99931'],
#  'number of tentatively identified compounds (tics) from voc analysis by gcms': ['p99871'],
#  'caffeine-13c': ['p99959']}

# %%
count = 0
all_params = list(filtered_params_2.keys())# + list(unfiltered_params_2.keys())
rows_containing_pollutant = []
names_of_pollutant = []
common_pollutants_p = []
reverse_params_def_dict = {}
for column in all_params:
    if np.any(names.str.match(column)):
        match_col = np.where(names.str.match(column))[0]
        print(column, match_col, type(match_col))
        rows_containing_pollutant += match_col.tolist()
        for i in range(len(match_col)):
            names_of_pollutant.append(column)
        for p_column in filtered_params_2[column]:
            reverse_params_def_dict[p_column] = column
            common_pollutants_p.append(p_column)
        count += 1
total_data = pd.concat([data_to_use[needed_params], data_to_use_numbers[common_pollutants_p]], axis=1)
#reverse_params_def_dict = {column:pollutant for column,pollutant in zip(common_pollutants_p,names_of_pollutant)}
# Out:
# nitrite [187] <class 'numpy.ndarray'>
# nitrate [186] <class 'numpy.ndarray'>
# phosphorus [208 209] <class 'numpy.ndarray'>
# cyanide [91] <class 'numpy.ndarray'>
# sodium [229] <class 'numpy.ndarray'>
# chloride [66] <class 'numpy.ndarray'>
# sulfate [232] <class 'numpy.ndarray'>
# fluoride [148] <class 'numpy.ndarray'>
# arsenic [19] <class 'numpy.ndarray'>
# barium [22] <class 'numpy.ndarray'>
# beryllium [33] <class 'numpy.ndarray'>
# boron [40] <class 'numpy.ndarray'>
# cadmium [58] <class 'numpy.ndarray'>
# chromium [81 82] <class 'numpy.ndarray'>
# cobalt [84] <class 'numpy.ndarray'>
# copper [85] <class 'numpy.ndarray'>
# iron [163] <class 'numpy.ndarray'>
# lead [166] <class 'numpy.ndarray'>
# manganese [169] <class 'numpy.ndarray'>
# thallium [239] <class 'numpy.ndarray'>
# molybdenum [182] <class 'numpy.ndarray'>
# nickel [185] <class 'numpy.ndarray'>
# silver [227] <class 'numpy.ndarray'>
# strontium [230] <class 'numpy.ndarray'>
# vanadium [260] <class 'numpy.ndarray'>
# antimony [18] <class 'numpy.ndarray'>
# aluminum [14] <class 'numpy.ndarray'>
# selenium [226] <class 'numpy.ndarray'>
# propachlor [214] <class 'numpy.ndarray'>
# hexazinone [157] <class 'numpy.ndarray'>
# butylate [54] <class 'numpy.ndarray'>
# bromacil [41] <class 'numpy.ndarray'>
# terbacil [234] <class 'numpy.ndarray'>
# diphenamid [132] <class 'numpy.ndarray'>
# simazine [228] <class 'numpy.ndarray'>
# prometryn [213] <class 'numpy.ndarray'>
# prometon [212] <class 'numpy.ndarray'>
# cyanazine [90] <class 'numpy.ndarray'>
# fonofos [149] <class 'numpy.ndarray'>
# radium-226 [223] <class 'numpy.ndarray'>
# alkalinity [13] <class 'numpy.ndarray'>
# alpha-hch [34] <class 'numpy.ndarray'>
# alpha-endosulfan [137] <class 'numpy.ndarray'>
# p,p'-dde [95] <class 'numpy.ndarray'>
# dicamba [102] <class 'numpy.ndarray'>
# dicrotophos [119] <class 'numpy.ndarray'>
# linuron [167] <class 'numpy.ndarray'>
# bentazon [25] <class 'numpy.ndarray'>
# dichlorvos [118] <class 'numpy.ndarray'>
# fluometuron [146] <class 'numpy.ndarray'>
# oxamyl [198] <class 'numpy.ndarray'>
# chlorpyrifos [80] <class 'numpy.ndarray'>
# aldrin [12] <class 'numpy.ndarray'>
# lindane [35] <class 'numpy.ndarray'>
# p,p'-ddd [94] <class 'numpy.ndarray'>
# p,p'-ddt [96] <class 'numpy.ndarray'>
# dieldrin [120] <class 'numpy.ndarray'>
# endrin [139] <class 'numpy.ndarray'>
# toxaphene [242] <class 'numpy.ndarray'>
# heptachlor [150 151] <class 'numpy.ndarray'>
# metolachlor [179] <class 'numpy.ndarray'>
# heptachlor epoxide [151] <class 'numpy.ndarray'>
# pcbs [211] <class 'numpy.ndarray'>
# malathion [168] <class 'numpy.ndarray'>
# parathion [199] <class 'numpy.ndarray'>
# diazinon [97] <class 'numpy.ndarray'>
# atrazine [20] <class 'numpy.ndarray'>
# 2,4-d [115 124 127 128] <class 'numpy.ndarray'>
# 2,4,5-t [249] <class 'numpy.ndarray'>
# alachlor [8] <class 'numpy.ndarray'>
# propham [219] <class 'numpy.ndarray'>
# acetochlor [2] <class 'numpy.ndarray'>
# picloram [210] <class 'numpy.ndarray'>
# oryzalin [197] <class 'numpy.ndarray'>
# norflurazon [195] <class 'numpy.ndarray'>
# methomyl [173] <class 'numpy.ndarray'>
# 2-methyl-4,6-dinitrophenol [126] <class 'numpy.ndarray'>
# diuron [135] <class 'numpy.ndarray'>
# dinoseb [130] <class 'numpy.ndarray'>
# chlorothalonil [78] <class 'numpy.ndarray'>
# carbofuran [62] <class 'numpy.ndarray'>
# carbaryl [60] <class 'numpy.ndarray'>
# bromoxynil [50] <class 'numpy.ndarray'>
# aldicarb [ 9 10 11] <class 'numpy.ndarray'>
# aldicarb sulfone [10] <class 'numpy.ndarray'>
# aldicarb sulfoxide [11] <class 'numpy.ndarray'>
# acifluorfen [6] <class 'numpy.ndarray'>
# benomyl [24] <class 'numpy.ndarray'>
# chlorimuron-ethyl [67] <class 'numpy.ndarray'>
# imazaquin [159] <class 'numpy.ndarray'>
# metalaxyl [171] <class 'numpy.ndarray'>
# propiconazole [220] <class 'numpy.ndarray'>
# hydrogen [158] <class 'numpy.ndarray'>
# cypermethrin [92] <class 'numpy.ndarray'>
# endosulfan sulfate [138] <class 'numpy.ndarray'>
# fenamiphos [145] <class 'numpy.ndarray'>
# iprodione [162] <class 'numpy.ndarray'>
# methidathion [172] <class 'numpy.ndarray'>
# phosmet [207] <class 'numpy.ndarray'>
# 4-chloro-2-methylphenol [70] <class 'numpy.ndarray'>
# warfarin [262] <class 'numpy.ndarray'>
# 1,4-dichlorobenzene [105] <class 'numpy.ndarray'>
# 2-methylnaphthalene [177] <class 'numpy.ndarray'>
# acetophenone [5] <class 'numpy.ndarray'>
# anthracene [17] <class 'numpy.ndarray'>
# bisphenol a [39] <class 'numpy.ndarray'>
# camphor [59] <class 'numpy.ndarray'>
# carbazole [61] <class 'numpy.ndarray'>
# diethyl phthalate [122] <class 'numpy.ndarray'>
# fluoranthene [147] <class 'numpy.ndarray'>
# isophorone [164] <class 'numpy.ndarray'>
# isopropylbenzene [89] <class 'numpy.ndarray'>
# naphthalene [183] <class 'numpy.ndarray'>
# p-cresol [87] <class 'numpy.ndarray'>
# phenanthrene [204] <class 'numpy.ndarray'>
# phenol [205] <class 'numpy.ndarray'>
# pyrene [222] <class 'numpy.ndarray'>
# perchlorate [202] <class 'numpy.ndarray'>
# ethane [140] <class 'numpy.ndarray'>
# propane [215] <class 'numpy.ndarray'>
# iodide [161] <class 'numpy.ndarray'>
# bromide [42] <class 'numpy.ndarray'>
# mercury [170] <class 'numpy.ndarray'>
# radium-228 [224] <class 'numpy.ndarray'>
# ethion [141] <class 'numpy.ndarray'>
# metribuzin [180] <class 'numpy.ndarray'>
# trifluralin [253] <class 'numpy.ndarray'>
# phorate [206] <class 'numpy.ndarray'>
# methyl parathion [178] <class 'numpy.ndarray'>
# tebuthiuron [233] <class 'numpy.ndarray'>
# molinate [181] <class 'numpy.ndarray'>
# benfluralin [23] <class 'numpy.ndarray'>
# terbufos [235] <class 'numpy.ndarray'>
# disulfoton [134] <class 'numpy.ndarray'>
# triallate [243] <class 'numpy.ndarray'>
# propanil [216] <class 'numpy.ndarray'>
# thiobencarb [240] <class 'numpy.ndarray'>
# dcpa [93] <class 'numpy.ndarray'>
# pendimethalin [200] <class 'numpy.ndarray'>
# napropamide [184] <class 'numpy.ndarray'>
# propargite [217] <class 'numpy.ndarray'>
# azinphos-methyl [21] <class 'numpy.ndarray'>

# %%
print(len(common_pollutants_p), len(reverse_params_def_dict))
# Out:
# 188 188

# %%
len(common_pollutants_p)
# Out:
# 188

# %%
#print(sorted(rows_containing_pollutant))
print(count)
# Out:
# 142

# %%
len(names_of_pollutant)
# Out:
# 150

# %%
chosen_ca_pollutant_info = ca_pollutant_info.iloc[rows_containing_pollutant, :]
chosen_ca_pollutant_info.shape
# Out:
# (150, 95)

# %%
data_cols = [column for column in chosen_ca_pollutant_info.columns.values.tolist()[7:] if "unit" not in column and "date" not in column and "Ag_Goals" not in column]#and "_2" not in column]
chosen_ca_pollutant_data = chosen_ca_pollutant_info[data_cols]
chosen_ca_pollutant_data.head()
# Out:
#      CA_Prim_MCL  CA_Prim_MCL_2  CA_Sec_MCL  CA_Sec_MCL_2  USEPA_Prim_MCL  \
# 187       1000.0            NaN         NaN           NaN          1000.0
# 186      10000.0            NaN         NaN           NaN         10000.0
# 208          NaN            NaN         NaN           NaN             NaN
# 209          NaN            NaN         NaN           NaN             NaN
# 91         150.0            NaN         NaN           NaN           200.0
#
#      USEPA_Prim_MCL_2  USEPA_Sec_MCL  USEPA_Sec_MCL_2  USEPA_MCL_Goal  \
# 187               NaN            NaN              NaN          1000.0
# 186               NaN            NaN              NaN         10000.0
# 208               NaN            NaN              NaN             NaN
# 209               NaN            NaN              NaN             NaN
# 91                NaN            NaN              NaN           200.0
#
#      USEPA_MCL_Goal_2        ...         CA_Inland_Health_DW  \
# 187               NaN        ...                         NaN
# 186               NaN        ...                         NaN
# 208               NaN        ...                         NaN
# 209               NaN        ...                         NaN
# 91                NaN        ...                       700.0
#
#      CA_Inland_Health_DW_2  CA_Inland_Health_Other  CA_Inland_Health_Other_2  \
# 187                    NaN                     NaN                       NaN
# 186                    NaN                     NaN                       NaN
# 208                    NaN                     NaN                       NaN
# 209                    NaN                     NaN                       NaN
# 91                     NaN                220000.0                       NaN
#
#      CA_BayEst_Health  CA_BayEst_Health_2  NAWQC_Health_WF  NAWQC_Health_WF_2  \
# 187               NaN                 NaN              NaN                NaN
# 186               NaN                 NaN          10000.0                NaN
# 208               NaN                 NaN              NaN                NaN
# 209               NaN                 NaN              NaN                NaN
# 91           220000.0                 NaN              4.0                NaN
#
#      NAWQC_Health_F  NAWQC_Health_F_2
# 187             NaN               NaN
# 186             NaN               NaN
# 208             NaN               NaN
# 209             NaN               NaN
# 91            400.0               NaN
#
# [5 rows x 42 columns]

# %%
# For checking the min values
#min_counts = []
#row_num = []
#for row in chosen_ca_pollutant_data.iterrows():
#    min_count = 999999999999
#    nonna_count = 0
#    for item in row[1]:
#        #if type(item) != float:
#        #    item = np.nan
#        if not np.isnan(item):
#            nonna_count += 1
#            if item < min_count:
#                min_count = item
#    
#    if min_count != 999999999999:
#        min_counts.append(min_count)
#        row_num.append(row[0])
#print(min_counts)
#print(row_num)

# %%
x = chosen_ca_pollutant_data.iloc[19,:]
x[(x.notna()) &  (x>0)]
# Out:
# CA_Prim_MCL              15.00
# USEPA_Prim_MCL           15.00
# CA_PHG                    0.20
# CalEPA_Cancer_Potency     4.10
# Prop65_Cancer             7.50
# Prop65_Repro              0.25
# Name: 166, dtype: float64

# %%
def find_threshold_minimum(x):
    x_data = x[(x.notna()) &  (x > 0)]
    if len(x_data) > 0:
        return min(x_data)
    else:
        return 999999999
    
min_thresholds = chosen_ca_pollutant_data.apply(find_threshold_minimum, axis=1)
min_thresholds_cols = chosen_ca_pollutant_data.idxmin(axis=1)
#min_thresholds_cols = min_thresholds_cols[min_thresholds_cols.notna()]
#min_thresholds = chosen_ca_pollutant_data[min_thresholds_cols]

# %%
for row in chosen_ca_pollutant_data.iterrows():
    x = row[1]
    x_data = x[(x.notna()) &  (x > 0)]
    if len(x_data) > 0:
        if max(x_data)/min(x_data) > 1000:
            print(chosen_ca_pollutant_info["Name1"][row[0]])
            print(min(x_data), max(x_data), )
            print("\n")
# Out:
# Cyanide
# 4.0 220000.0
#
#
# Arsenic
# 0.0014 10.0
#
#
# Beryllium
# 1.0 30000.0
#
#
# Cadmium
# 0.0023 5.0
#
#
# Chromium(VI)
# 0.02 21.0
#
#
# Antimony
# 1.0 4300.0
#
#
# alpha-HCH
# 0.0039 500.0
#
#
# p,p'-DDE
# 0.00059 1.0
#
#
# Aldrin
# 8e-05 0.3
#
#
# Lindane
# 0.019 500.0
#
#
# p,p'-DDD
# 0.00083 1.0
#
#
# p,p'-DDT
# 0.00059 3.5
#
#
# Dieldrin
# 0.00014 0.5
#
#
# Toxaphene
# 0.00073 8.75
#
#
# Heptachlor
# 0.00021 10.0
#
#
# 151    Heptachlor epoxide
# 151    Heptachlor epoxide
# Name: Name1, dtype: object
# 0.0001 10.0
#
#
# 151    Heptachlor epoxide
# 151    Heptachlor epoxide
# Name: Name1, dtype: object
# 0.0001 10.0
#
#
# PCBs
# 0.00017 50.0
#
#
# 2,4-Dinitrophenol
# 10.0 14000.0
#
#
# 2,4-Dinitrotoluene
# 0.05 1000.0
#
#
# Alachlor
# 0.4 700.0
#
#
# Acifluorfen
# 1.0 2000.0
#
#
# Phenol
# 2000.0 4600000.0

# %%
names_of_pollutant
# Out:
# ['nitrite',
#  'nitrate',
#  'phosphorus',
#  'phosphorus',
#  'cyanide',
#  'sodium',
#  'chloride',
#  'sulfate',
#  'fluoride',
#  'arsenic',
#  'barium',
#  'beryllium',
#  'boron',
#  'cadmium',
#  'chromium',
#  'chromium',
#  'cobalt',
#  'copper',
#  'iron',
#  'lead',
#  'manganese',
#  'thallium',
#  'molybdenum',
#  'nickel',
#  'silver',
#  'strontium',
#  'vanadium',
#  'antimony',
#  'aluminum',
#  'selenium',
#  'propachlor',
#  'hexazinone',
#  'butylate',
#  'bromacil',
#  'terbacil',
#  'diphenamid',
#  'simazine',
#  'prometryn',
#  'prometon',
#  'cyanazine',
#  'fonofos',
#  'radium-226',
#  'alkalinity',
#  'alpha-hch',
#  'alpha-endosulfan',
#  "p,p'-dde",
#  'dicamba',
#  'dicrotophos',
#  'linuron',
#  'bentazon',
#  'dichlorvos',
#  'fluometuron',
#  'oxamyl',
#  'chlorpyrifos',
#  'aldrin',
#  'lindane',
#  "p,p'-ddd",
#  "p,p'-ddt",
#  'dieldrin',
#  'endrin',
#  'toxaphene',
#  'heptachlor',
#  'heptachlor',
#  'metolachlor',
#  'heptachlor epoxide',
#  'pcbs',
#  'malathion',
#  'parathion',
#  'diazinon',
#  'atrazine',
#  '2,4-d',
#  '2,4-d',
#  '2,4-d',
#  '2,4-d',
#  '2,4,5-t',
#  'alachlor',
#  'propham',
#  'acetochlor',
#  'picloram',
#  'oryzalin',
#  'norflurazon',
#  'methomyl',
#  '2-methyl-4,6-dinitrophenol',
#  'diuron',
#  'dinoseb',
#  'chlorothalonil',
#  'carbofuran',
#  'carbaryl',
#  'bromoxynil',
#  'aldicarb',
#  'aldicarb',
#  'aldicarb',
#  'aldicarb sulfone',
#  'aldicarb sulfoxide',
#  'acifluorfen',
#  'benomyl',
#  'chlorimuron-ethyl',
#  'imazaquin',
#  'metalaxyl',
#  'propiconazole',
#  'hydrogen',
#  'cypermethrin',
#  'endosulfan sulfate',
#  'fenamiphos',
#  'iprodione',
#  'methidathion',
#  'phosmet',
#  '4-chloro-2-methylphenol',
#  'warfarin',
#  '1,4-dichlorobenzene',
#  '2-methylnaphthalene',
#  'acetophenone',
#  'anthracene',
#  'bisphenol a',
#  'camphor',
#  'carbazole',
#  'diethyl phthalate',
#  'fluoranthene',
#  'isophorone',
#  'isopropylbenzene',
#  'naphthalene',
#  'p-cresol',
#  'phenanthrene',
#  'phenol',
#  'pyrene',
#  'perchlorate',
#  'ethane',
#  'propane',
#  'iodide',
#  'bromide',
#  'mercury',
#  'radium-228',
#  'ethion',
#  'metribuzin',
#  'trifluralin',
#  'phorate',
#  'methyl parathion',
#  'tebuthiuron',
#  'molinate',
#  'benfluralin',
#  'terbufos',
#  'disulfoton',
#  'triallate',
#  'propanil',
#  'thiobencarb',
#  'dcpa',
#  'pendimethalin',
#  'napropamide',
#  'propargite',
#  'azinphos-methyl']

# %%
len(min_thresholds)
# Out:
# 150

# %%
len(min_thresholds_cols)
# Out:
# 150

# %%
len(rows_containing_pollutant)
# Out:
# 150

# %%
ca_pollutant_thresholds = pd.DataFrame({"Pollutant":names_of_pollutant, "Min Value":min_thresholds, "Threshold Adhered To":min_thresholds_cols})
ca_pollutant_thresholds = ca_pollutant_thresholds[ca_pollutant_thresholds["Threshold Adhered To"].notna()]
ca_pollutant_thresholds.head()
# Out:
#       Pollutant  Min Value Threshold Adhered To
# 187     nitrite      700.0       USEPA_IRIS_RfD
# 186     nitrate    10000.0          CA_Prim_MCL
# 209  phosphorus        0.1   USEPA_HA_NonCancer
# 91      cyanide        4.0      NAWQC_Health_WF
# 229      sodium    20000.0   USEPA_HA_NonCancer

# %%
common_pollutants_p = []
reverse_params_def_dict = {}
for pollutant in ca_pollutant_thresholds["Pollutant"]:
    for column in filtered_params_2[pollutant]:
        reverse_params_def_dict[column] = pollutant
        common_pollutants_p.append(column)

# %%
ca_pollutant_thresholds.shape
# Out:
# (140, 3)

# %%
common_pollutants_p
# Out:
# ['p00613',
#  'p71856',
#  'p00618',
#  'p71851',
#  'p00666',
#  'p00721',
#  'p00930',
#  'p00940',
#  'p00945',
#  'p00950',
#  'p91002',
#  'p01000',
#  'p01001',
#  'p01003',
#  'p01005',
#  'p01006',
#  'p01010',
#  'p01020',
#  'p01025',
#  'p01026',
#  'p01028',
#  'p01030',
#  'p01031',
#  'p01030',
#  'p01031',
#  'p01040',
#  'p01041',
#  'p01043',
#  'p01044',
#  'p01046',
#  'p01170',
#  'p01049',
#  'p01050',
#  'p01052',
#  'p01054',
#  'p01056',
#  'p01057',
#  'p01060',
#  'p01065',
#  'p01066',
#  'p01068',
#  'p01075',
#  'p01076',
#  'p01080',
#  'p01085',
#  'p01095',
#  'p01106',
#  'p01145',
#  'p01146',
#  'p01148',
#  'p04024',
#  'p04025',
#  'p04028',
#  'p04029',
#  'p63189',
#  'p04032',
#  'p82665',
#  'p04033',
#  'p04035',
#  'p04036',
#  'p04037',
#  'p63226',
#  'p04041',
#  'p04095',
#  'p09503',
#  'p09511',
#  'p34253',
#  'p34362',
#  'p39389',
#  'p34653',
#  'p39368',
#  'p38442',
#  'p38454',
#  'p38478',
#  'p82666',
#  'p38711',
#  'p38775',
#  'p38811',
#  'p38866',
#  'p38933',
#  'p63195',
#  'p39333',
#  'p39341',
#  'p39343',
#  'p39363',
#  'p39373',
#  'p39381',
#  'p39383',
#  'p39393',
#  'p39403',
#  'p39413',
#  'p39413',
#  'p39415',
#  'p63218',
#  'p39423',
#  'p39519',
#  'p39532',
#  'p39542',
#  'p39572',
#  'p63198',
#  'p39632',
#  'p63182',
#  'p39732',
#  'p39732',
#  'p39732',
#  'p39732',
#  'p39742',
#  'p99958',
#  'p46342',
#  'p49236',
#  'p49260',
#  'p49291',
#  'p49292',
#  'p49293',
#  'p49296',
#  'p49299',
#  'p49300',
#  'p49301',
#  'p49306',
#  'p49309',
#  'p82674',
#  'p49310',
#  'p82680',
#  'p49311',
#  'p49312',
#  'p49312',
#  'p49312',
#  'p49313',
#  'p49314',
#  'p49315',
#  'p50300',
#  'p50306',
#  'p50356',
#  'p50359',
#  'p61596',
#  'p50471',
#  'p61586',
#  'p61590',
#  'p61591',
#  'p61593',
#  'p61598',
#  'p61601',
#  'p62024',
#  'p63163',
#  'p63168',
#  'p63178',
#  'p63180',
#  'p63188',
#  'p63194',
#  'p63202',
#  'p63208',
#  'p63212',
#  'p63213',
#  'p63220',
#  'p63225',
#  'p63227',
#  'p63790',
#  'p71865',
#  'p71870',
#  'p71890',
#  'p71895',
#  'p71921',
#  'p81366',
#  'p82346',
#  'p82630',
#  'p82661',
#  'p82664',
#  'p82667',
#  'p82670',
#  'p82671',
#  'p82673',
#  'p82675',
#  'p82677',
#  'p82678',
#  'p82679',
#  'p82681',
#  'p82682',
#  'p82683',
#  'p82684',
#  'p82685',
#  'p82686']

# %%
# Parallel test for new pollutant data - WORKS
column = "p01010"
threshold = ca_pollutant_thresholds["Min Value"][ca_pollutant_thresholds["Pollutant"]==reverse_params_def_dict[column]]
actual_threshold = threshold.values[0]

# %%
# passed_threshold = gives gauges that exceeded threshold
passed_threshold = total_data[column][total_data[column].notna()] > actual_threshold
has_passed_site = total_data["site_no"][total_data[column].notna()][passed_threshold]
has_passed_nums = total_data[column][total_data[column].notna()][passed_threshold]

# %%
total_data.columns.values.tolist()
# Out:
# ['site_no',
#  'sample_dt',
#  'sample_tm',
#  'p00613',
#  'p71856',
#  'p00618',
#  'p71851',
#  'p00666',
#  'p00721',
#  'p00930',
#  'p00940',
#  'p00945',
#  'p00950',
#  'p91002',
#  'p01000',
#  'p01001',
#  'p01003',
#  'p01005',
#  'p01006',
#  'p01010',
#  'p01020',
#  'p01025',
#  'p01026',
#  'p01028',
#  'p01030',
#  'p01031',
#  'p01035',
#  'p01036',
#  'p01040',
#  'p01041',
#  'p01043',
#  'p01044',
#  'p01046',
#  'p01170',
#  'p01049',
#  'p01050',
#  'p01052',
#  'p01054',
#  'p01056',
#  'p01057',
#  'p01060',
#  'p01065',
#  'p01066',
#  'p01068',
#  'p01075',
#  'p01076',
#  'p01080',
#  'p01085',
#  'p01095',
#  'p01106',
#  'p01145',
#  'p01146',
#  'p01148',
#  'p04024',
#  'p04025',
#  'p04028',
#  'p04029',
#  'p63189',
#  'p04032',
#  'p82665',
#  'p04033',
#  'p04035',
#  'p04036',
#  'p04037',
#  'p63226',
#  'p04041',
#  'p04095',
#  'p09503',
#  'p09511',
#  'p29801',
#  'p29802',
#  'p39036',
#  'p39086',
#  'p34253',
#  'p34362',
#  'p39389',
#  'p34653',
#  'p39368',
#  'p38442',
#  'p38454',
#  'p38478',
#  'p82666',
#  'p38711',
#  'p38775',
#  'p38811',
#  'p38866',
#  'p38933',
#  'p63195',
#  'p39333',
#  'p39341',
#  'p39343',
#  'p39363',
#  'p39373',
#  'p39381',
#  'p39383',
#  'p39393',
#  'p39403',
#  'p39413',
#  'p39415',
#  'p63218',
#  'p39423',
#  'p39519',
#  'p39532',
#  'p39542',
#  'p39572',
#  'p63198',
#  'p39632',
#  'p63182',
#  'p39732',
#  'p39742',
#  'p99958',
#  'p46342',
#  'p49236',
#  'p49260',
#  'p49291',
#  'p49292',
#  'p49293',
#  'p49296',
#  'p49299',
#  'p49300',
#  'p49301',
#  'p49306',
#  'p49309',
#  'p82674',
#  'p49310',
#  'p82680',
#  'p49311',
#  'p49312',
#  'p49313',
#  'p49314',
#  'p49315',
#  'p50300',
#  'p50306',
#  'p50356',
#  'p50359',
#  'p61596',
#  'p50471',
#  'p51189',
#  'p61586',
#  'p61590',
#  'p61591',
#  'p61593',
#  'p61598',
#  'p61601',
#  'p61633',
#  'p62024',
#  'p63163',
#  'p63168',
#  'p63178',
#  'p63180',
#  'p63188',
#  'p63192',
#  'p63194',
#  'p63202',
#  'p63208',
#  'p63212',
#  'p63213',
#  'p63220',
#  'p63222',
#  'p63224',
#  'p63225',
#  'p63227',
#  'p63790',
#  'p68824',
#  'p68832',
#  'p68826',
#  'p68834',
#  'p71865',
#  'p71870',
#  'p71890',
#  'p71895',
#  'p71921',
#  'p81366',
#  'p82346',
#  'p82630',
#  'p82661',
#  'p82664',
#  'p82667',
#  'p82670',
#  'p82671',
#  'p82673',
#  'p82675',
#  'p82677',
#  'p82678',
#  'p82679',
#  'p82681',
#  'p82682',
#  'p82683',
#  'p82684',
#  'p82685',
#  'p82686']

# %%
to_write_to_file = ""
header = "Site\tPollutant\tDate\t% Error\tValue\tThreshold\tThreshold Adhered To\n"
formatSTR = "{}\t{}\t{}\t{}\t{}\t{}\t{}\n"
pollutant_col = "Pollutant"
threshold_col = "Min Value"
which_threshold_col = "Threshold Adhered To"
date_col = "sample_dt"

# %%
reverse_params_def_dict
# Out:
# {'p00613': 'nitrite',
#  'p71856': 'nitrite',
#  'p00618': 'nitrate',
#  'p71851': 'nitrate',
#  'p00666': 'phosphorus',
#  'p00721': 'cyanide',
#  'p00930': 'sodium',
#  'p00940': 'chloride',
#  'p00945': 'sulfate',
#  'p00950': 'fluoride',
#  'p91002': 'fluoride',
#  'p01000': 'arsenic',
#  'p01001': 'arsenic',
#  'p01003': 'arsenic',
#  'p01005': 'barium',
#  'p01006': 'barium',
#  'p01010': 'beryllium',
#  'p01020': 'boron',
#  'p01025': 'cadmium',
#  'p01026': 'cadmium',
#  'p01028': 'cadmium',
#  'p01030': 'chromium',
#  'p01031': 'chromium',
#  'p01040': 'copper',
#  'p01041': 'copper',
#  'p01043': 'copper',
#  'p01044': 'iron',
#  'p01046': 'iron',
#  'p01170': 'iron',
#  'p01049': 'lead',
#  'p01050': 'lead',
#  'p01052': 'lead',
#  'p01054': 'manganese',
#  'p01056': 'manganese',
#  'p01057': 'thallium',
#  'p01060': 'molybdenum',
#  'p01065': 'nickel',
#  'p01066': 'nickel',
#  'p01068': 'nickel',
#  'p01075': 'silver',
#  'p01076': 'silver',
#  'p01080': 'strontium',
#  'p01085': 'vanadium',
#  'p01095': 'antimony',
#  'p01106': 'aluminum',
#  'p01145': 'selenium',
#  'p01146': 'selenium',
#  'p01148': 'selenium',
#  'p04024': 'propachlor',
#  'p04025': 'hexazinone',
#  'p04028': 'butylate',
#  'p04029': 'bromacil',
#  'p63189': 'bromacil',
#  'p04032': 'terbacil',
#  'p82665': 'terbacil',
#  'p04033': 'diphenamid',
#  'p04035': 'simazine',
#  'p04036': 'prometryn',
#  'p04037': 'prometon',
#  'p63226': 'prometon',
#  'p04041': 'cyanazine',
#  'p04095': 'fonofos',
#  'p09503': 'radium-226',
#  'p09511': 'radium-226',
#  'p34253': 'alpha-hch',
#  'p34362': 'alpha-endosulfan',
#  'p39389': 'alpha-endosulfan',
#  'p34653': "p,p'-dde",
#  'p39368': "p,p'-dde",
#  'p38442': 'dicamba',
#  'p38454': 'dicrotophos',
#  'p38478': 'linuron',
#  'p82666': 'linuron',
#  'p38711': 'bentazon',
#  'p38775': 'dichlorvos',
#  'p38811': 'fluometuron',
#  'p38866': 'oxamyl',
#  'p38933': 'chlorpyrifos',
#  'p63195': 'chlorpyrifos',
#  'p39333': 'aldrin',
#  'p39341': 'lindane',
#  'p39343': 'lindane',
#  'p39363': "p,p'-ddd",
#  'p39373': "p,p'-ddt",
#  'p39381': 'dieldrin',
#  'p39383': 'dieldrin',
#  'p39393': 'endrin',
#  'p39403': 'toxaphene',
#  'p39413': 'heptachlor',
#  'p39415': 'metolachlor',
#  'p63218': 'metolachlor',
#  'p39423': 'heptachlor epoxide',
#  'p39519': 'pcbs',
#  'p39532': 'malathion',
#  'p39542': 'parathion',
#  'p39572': 'diazinon',
#  'p63198': 'diazinon',
#  'p39632': 'atrazine',
#  'p63182': 'atrazine',
#  'p39732': '2,4-d',
#  'p39742': '2,4,5-t',
#  'p99958': '2,4,5-t',
#  'p46342': 'alachlor',
#  'p49236': 'propham',
#  'p49260': 'acetochlor',
#  'p49291': 'picloram',
#  'p49292': 'oryzalin',
#  'p49293': 'norflurazon',
#  'p49296': 'methomyl',
#  'p49299': '2-methyl-4,6-dinitrophenol',
#  'p49300': 'diuron',
#  'p49301': 'dinoseb',
#  'p49306': 'chlorothalonil',
#  'p49309': 'carbofuran',
#  'p82674': 'carbofuran',
#  'p49310': 'carbaryl',
#  'p82680': 'carbaryl',
#  'p49311': 'bromoxynil',
#  'p49312': 'aldicarb',
#  'p49313': 'aldicarb sulfone',
#  'p49314': 'aldicarb sulfoxide',
#  'p49315': 'acifluorfen',
#  'p50300': 'benomyl',
#  'p50306': 'chlorimuron-ethyl',
#  'p50356': 'imazaquin',
#  'p50359': 'metalaxyl',
#  'p61596': 'metalaxyl',
#  'p50471': 'propiconazole',
#  'p61586': 'cypermethrin',
#  'p61590': 'endosulfan sulfate',
#  'p61591': 'fenamiphos',
#  'p61593': 'iprodione',
#  'p61598': 'methidathion',
#  'p61601': 'phosmet',
#  'p62024': 'warfarin',
#  'p63163': '1,4-dichlorobenzene',
#  'p63168': '2-methylnaphthalene',
#  'p63178': 'acetophenone',
#  'p63180': 'anthracene',
#  'p63188': 'bisphenol a',
#  'p63194': 'carbazole',
#  'p63202': 'diethyl phthalate',
#  'p63208': 'fluoranthene',
#  'p63212': 'isophorone',
#  'p63213': 'isopropylbenzene',
#  'p63220': 'naphthalene',
#  'p63225': 'phenol',
#  'p63227': 'pyrene',
#  'p63790': 'perchlorate',
#  'p71865': 'iodide',
#  'p71870': 'bromide',
#  'p71890': 'mercury',
#  'p71895': 'mercury',
#  'p71921': 'mercury',
#  'p81366': 'radium-228',
#  'p82346': 'ethion',
#  'p82630': 'metribuzin',
#  'p82661': 'trifluralin',
#  'p82664': 'phorate',
#  'p82667': 'methyl parathion',
#  'p82670': 'tebuthiuron',
#  'p82671': 'molinate',
#  'p82673': 'benfluralin',
#  'p82675': 'terbufos',
#  'p82677': 'disulfoton',
#  'p82678': 'triallate',
#  'p82679': 'propanil',
#  'p82681': 'thiobencarb',
#  'p82682': 'dcpa',
#  'p82683': 'pendimethalin',
#  'p82684': 'napropamide',
#  'p82685': 'propargite',
#  'p82686': 'azinphos-methyl'}

# %%
for column in common_pollutants_p:
    columns_with_pollutant_info = ca_pollutant_thresholds[pollutant_col]==reverse_params_def_dict[column]
    threshold = ca_pollutant_thresholds[threshold_col][columns_with_pollutant_info].values[0]
    passed_threshold = total_data[column][total_data[column].notna()] > threshold
    has_passed_site = total_data["site_no"][total_data[column].notna()][passed_threshold]
    has_passed_nums = total_data[column][total_data[column].notna()][passed_threshold]
    has_passed_pcts = (has_passed_nums - threshold)/threshold
    has_passed_date = total_data[date_col][total_data[column].notna()][passed_threshold]
    which_threshold = ca_pollutant_thresholds[which_threshold_col][ca_pollutant_thresholds[pollutant_col]==reverse_params_def_dict[column]].values[0]
    for i in range(len(has_passed_site)):
        to_add = formatSTR.format(has_passed_site.iloc[i], reverse_params_def_dict[column], 
                                  has_passed_date.iloc[i], has_passed_pcts.iloc[i], 
                                  has_passed_nums.iloc[i], threshold, which_threshold)
        to_write_to_file += to_add

# %%
file = open("potentially_a_bipartite_US.tsv", "w")
file.write(header + to_write_to_file)
file.close()

# %% [markdown]
# ## PUT IT INTO NETWORKX

# %%
#reload the file
graph_info = pd.read_csv("potentially_a_bipartite_US.tsv", sep="\t")
graph_info.head()

#df.groupby(['Col1', 'Col2']).size()
graph_site_pollutant = graph_info.groupby(["Site", "Pollutant"]).size().reset_index()[["Site", "Pollutant"]]
graph_site_pollutant.head()
# Out:
#        Site  Pollutant
# 0  10264120  manganese
# 1  10278300    arsenic
# 2  10278300  beryllium
# 3  10278300    cadmium
# 4  10278300       lead

# %%
edges = [tuple(row[1]) for row in graph_site_pollutant.iterrows()]

# %%
pollutant_graph = nx.Graph()

# %%
#pollutant_graph.add_nodes_from(data_to_use['site_no'], bipartite=0)
#pollutant_graph.add_nodes_from(filtered_params_2.keys(), bipartite=1)
#pollutant_graph.add_nodes_from(graph_site_pollutant["Site"], bipartite=0)
#pollutant_graph.add_nodes_from(graph_site_pollutant["Pollutant"], bipartite=1)
pollutant_graph.add_edges_from(edges)

# %%
sites, pollutants = bipartite.sets(pollutant_graph)

# %%
max([len(i) for i in nx.connected_components(pollutant_graph)])
# Out:
# 824

# %%
pos = nx.spring_layout(pollutant_graph)

# %%
plt.figure(figsize=(12,8))

communities = [sites, pollutants]
colors = ["salmon", "lightblue"]
nx.draw_networkx_edges(pollutant_graph, pos=pos, width = 1, edge_color="darkgray")
for community, color in zip(communities, colors):
    nx.draw_networkx_nodes(pollutant_graph, pos=pos, 
                           nodelist=community,
                           node_color=color,
                           with_labels=False,
                           node_size=40)

    #nx.draw_networkx_labels(pollutant_graph,pos=pos)
_=plt.axis("off")
# Out:
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
site_graph = bipartite.projected_graph(pollutant_graph, sites)
[len(i) for i in nx.connected_components(site_graph)]
# Out:
# [773]

# %%
pos = nx.spring_layout(site_graph, k=0.0001)

# %%
plt.figure(figsize=(12,8))
nx.draw_networkx_edges(site_graph, pos=pos, width = 1, edge_color="darkgray")
nx.draw_networkx_nodes(site_graph, pos=pos, with_labels=False)
_=plt.axis("off")
# Out:
# /usr/local/Cellar/python3/3.6.2/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):

# %%
pollute_graph = bipartite.projected_graph(pollutant_graph, pollutants)
[len(i) for i in nx.connected_components(pollute_graph)]
# Out:
# [51]

# %% [markdown]
# ## TEST - IT WORKS!!!!

# %% [markdown]
# column = "p01010"
# threshold = pollutant_info["Human Health for the consumption of\xa0Water + Organism (µg/L)"][pollutant_info["Pollutant (P = priority pollutant)"]==reverse_params_def_dict[column]]
# actual_threshold = threshold.values[0]
# print("Column:", reverse_params_def_dict[column], "\tThreshold:", actual_threshold)

# %% [markdown]
# passed_threshold = total_data[column][total_data[column].notna()] > actual_threshold
# has_passed_site = total_data["site_no"][total_data[column].notna()][passed_threshold]
# has_passed_nums = total_data[column][total_data[column].notna()][passed_threshold]
# #len(passed_threshold)
# #len(total_data)

# %% [markdown]
# ## Let's do this

# %% [markdown]
# to_write_to_file = ""
# formatSTR = "{}\t{}\t{}\n"
# pollutant_col = "Pollutant (P = priority pollutant)"
# threshold_col = "Human Health for the consumption of\xa0Water + Organism (µg/L)"

# %% [markdown]
# for column in common_pollutants_p:
#     threshold = pollutant_info[threshold_col][pollutant_info[pollutant_col]==reverse_params_def_dict[column]].values[0]
#     passed_threshold = total_data[column][total_data[column].notna()] > threshold
#     has_passed_site = total_data["site_no"][total_data[column].notna()][passed_threshold]
#     has_passed_nums = total_data[column][total_data[column].notna()][passed_threshold]
#
#     for i in range(len(has_passed_site)):
#         to_add = formatSTR.format(has_passed_site.iloc[i], reverse_params_def_dict[column], has_passed_nums.iloc[i])
#         to_write_to_file += to_add

# %% [markdown]
# file = open("potentially_a_bipartite.tsv", "w")
# file.write(to_write_to_file)
# file.close()

# %% [markdown]
# len(common_pollutants_p)

# %% [markdown]
# pollutant_info.shape

# %% [markdown]
# ### Tangent: Looking at the amount of data per parameter

# %%
# Let's see how much data we have for each parameter...
params_counts_dict = {}
for param in a:
    count = a.shape[0] - sum(a[param].isna())
    if count > 0:
        params_counts_dict[params_def_dict[param]] = count
    
    #print(params_def_dict[param] + ":", count)
params_counts = list(params_counts_dict.values())

# %%
plt.hist(list(params_counts_dict.values()))

# %%
counts_of_counts = {}
for count in params_counts_dict.values():
    if count not in counts_of_counts:
        counts_of_counts[count] = 0
    counts_of_counts[count] += 1

param_counts = list(params_counts_dict.values())
count_counts = list(counts_of_counts.values())
bin_edges = np.logspace(np.log10(min(param_counts)), 
                        np.log10(max(param_counts)),
                        num = 10)
density, _ = np.histogram(param_counts, bins=bin_edges, density=True)

# %%
log_be = np.log10(bin_edges)
x = 10**((log_be[1:] + log_be[:-1])/2)

plt.loglog(x, density, marker='o', linestyle='none')

# %%
log_be
