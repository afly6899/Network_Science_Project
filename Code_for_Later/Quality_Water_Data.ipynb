# %% [markdown]
# # Water Quality Network
# For our network project, Cassie and I are thinking of creating a bipartite network where the nodes are pollutants and the links are water facilities whose measurements of those pollutants are above the threshold. By doing this linking, we hope to see what the biggest pollutants are, how pollutants might connect to one another, and if there are any pollutants that we should be worried about.

# %% [markdown]
# ## Data Sources
# We got our data from USGS (U.S. Geological Survey). I'll need to get the exact link later.

# %% [markdown]
# ## Looking at the data
# Since I'm not too familiar with the data, let's load it in and take a look. There's some preliminary things that I do know, which will be come prevelant when you look at the code. For instance, you can break up the code into chunks by splitting on instances of "#\n". The # comes from the file header and most "sections" within the header are separated by # followed by a new line. The last item of the split is the actual data.
#
# Let's start by loading in everything!

# %%
import re
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def load_data(file_name):
    data = []
    with open(file_name, 'r') as file:
        data = file.read().split("#\n")

    if not data:
        print("File {} was unable to be read.".format(file_name))
    return data

# %%
file_name = "LA_Water_Quality_Data.txt"
data = load_data(file_name)
print("Number of sections:", len(data))
print("2nd section:", data[2], sep = "\n")
print("Number of characters in actual data:", len(data[15]))
# Out:
# Number of sections: 16
# 2nd section:
# # U.S. Geological Survey
# #
# # This file contains selected water-quality data for stations in the National Water Information
# # System water-quality database.  Explanation of codes found in this file are followed by
# # the retrieved data.
#
# Number of characters in actual data: 9736982

# %% [markdown]
# Great! We have 15 chunks of text when doing that split (which feels a bit better than doing it line-by-line). Here's a breakdown of what's inside:
#     #  0:                               #  8: coll_ent_cd
#     #  1: File created...               #  9: medium_cd
#     #  2: U.S. Geological Survey        # 10: tu_id
#     #  3: The data you have...          # 11: body_part_id
#     #  4: To view additional...         # 12: remark_cd
#     #  5: Param_id      - parameter     # 13: Data for the following sites...
#     #  6: sample_start_time_datum_cd    # 14: WARNING: some preadsheet...
#     #  7: tm_datum_rlbty_cd             # 15: Data!
#
# I've already glanced at the file in Excel and figured out how to parse all of the parameters and their descriptions, which will probably be useful later on.

# %%
# inputs the part of the header that contains the parameter label followed by its meaning
# outputs a dictionary where the key is the label (lower case) and the value is the description
def get_parameter_def(param_header):
    params_dict = {}
    params_type = {}
    params = param_header.split("\n")
    params_pattern = re.compile("# +(\w+) +- +(.+)")

    for param in params:
        a = params_pattern.search(param)

        if a: 
            #print(first_t, a.group(1), a.group(2))
            params_dict[a.group(1).lower()] = a.group(2)
            #print(a.group(1) + ":", a.group(2).split(',')[-1])

    return params_dict

# %%
params_dict = get_parameter_def(data[5])
print("Total number of parameters measured:", len(params_dict))
# Out:
# Total number of parameters measured: 1046

# %%
params_dict
# Out:
# {'agency_cd': 'Agency Code',
#  'site_no': 'Station number',
#  'sample_dt': 'Begin date',
#  'sample_tm': 'Begin time',
#  'sample_end_dt': 'End date',
#  'sample_end_tm': 'End time',
#  'sample_start_time_datum_cd': 'Time datum',
#  'tm_datum_rlbty_cd': 'Time datum reliability code',
#  'coll_ent_cd': 'Agency Collecting Sample Code',
#  'medium_cd': 'Medium code',
#  'tu_id': 'Taxonomic unit code',
#  'body_part_id': 'Body part code',
#  'p00003': 'Sampling depth, feet',
#  'p00004': 'Stream width, feet',
#  'p00005': 'Location in cross section, fraction of total depth, percent',
#  'p00008': 'Sample accounting number',
#  'p00009': 'Location in cross section, distance from left bank looking downstream, feet',
#  'p00010': 'Temperature, water, degrees Celsius',
#  'p00011': 'Temperature, water, degrees Fahrenheit',
#  'p00020': 'Temperature, air, degrees Celsius',
#  'p00021': 'Temperature, air, degrees Fahrenheit',
#  'p00025': 'Barometric pressure, millimeters of mercury',
#  'p00028': 'Agency analyzing sample, code',
#  'p00029': 'Project number',
#  'p00032': 'Cloud cover, percent',
#  'p00058': 'Flow rate of well, gallons per minute',
#  'p00059': 'Flow rate, instantaneous, gallons per minute',
#  'p00060': 'Discharge, cubic feet per second',
#  'p00061': 'Discharge, instantaneous, cubic feet per second',
#  'p00065': 'Gage height, feet',
#  'p00070': 'Turbidity, water, unfiltered, Jackson Turbidity Units',
#  'p00075': 'Turbidity, water, unfiltered, Hellige turbidimeter, milligrams per liter as silicon dioxide',
#  'p00076': 'Turbidity, water, unfiltered, nephelometric turbidity units',
#  'p00080': 'Color, water, filtered, platinum cobalt units',
#  'p00085': 'Odor at room temperature, threshold odor number',
#  'p00090': 'Oxidation reduction potential, reference electrode not specified, millivolts',
#  'p00095': 'Specific conductance, water, unfiltered, microsiemens per centimeter at 25 degrees Celsius',
#  'p00098': 'Sampling depth, meters',
#  'p00191': 'Hydrogen ion, water, unfiltered, calculated, milligrams per liter',
#  'p00300': 'Dissolved oxygen, water, unfiltered, milligrams per liter',
#  'p00301': 'Dissolved oxygen, water, unfiltered, percent of saturation',
#  'p00310': 'Biochemical oxygen demand, water, unfiltered, 5 days at 20 degrees Celsius, milligrams per liter',
#  'p00335': 'Chemical oxygen demand, low level, water, unfiltered, milligrams per liter',
#  'p00340': 'Chemical oxygen demand, high level, water, unfiltered, milligrams per liter',
#  'p00400': 'pH, water, unfiltered, field, standard units',
#  'p00403': 'pH, water, unfiltered, laboratory, standard units',
#  'p00405': 'Carbon dioxide, water, unfiltered, milligrams per liter',
#  'p00410': 'Acid neutralizing capacity, water, unfiltered, fixed endpoint (pH 4.5) titration, field, milligrams per liter as calcium carbonate',
#  'p00419': 'Acid neutralizing capacity, water, unfiltered, inflection-point titration method (incremental titration method), field, milligrams per liter as calcium carbonate',
#  'p00440': 'Bicarbonate, water, unfiltered, fixed endpoint (pH 4.5) titration, field, milligrams per liter',
#  'p00445': 'Carbonate, water, unfiltered, fixed endpoint (pH 8.3) titration, field, milligrams per liter',
#  'p00447': 'Carbonate, water, unfiltered, inflection-point titration method (incremental titration method), field, milligrams per liter',
#  'p00450': 'Bicarbonate, water, unfiltered, inflection-point titration method (incremental titration method), field, milligrams per liter',
#  'p00452': 'Carbonate, water, filtered, inflection-point titration method (incremental titration method), field, milligrams per liter',
#  'p00453': 'Bicarbonate, water, filtered, inflection-point titration method (incremental titration method), field, milligrams per liter',
#  'p00510': 'Total solids remaining after ignition, water, unfiltered, milligrams per liter',
#  'p00515': 'Dissolved solids dried at 105 degrees Celsius, water, filtered, milligrams per liter',
#  'p00520': 'Loss on ignition of dissolved solids, water, filtered, milligrams per liter',
#  'p00530': 'Suspended solids, water, unfiltered, milligrams per liter',
#  'p00535': 'Loss on ignition of suspended solids, water, unfiltered, milligrams per liter',
#  'p00540': 'Suspended solids remaining after ignition, water, unfiltered, milligrams per liter',
#  'p00550': 'Oil and grease, water, unfiltered, recoverable, milligrams per liter',
#  'p00556': 'Oil and grease, water, unfiltered, freon extraction, gravimetric, recoverable, milligrams per liter',
#  'p00572': 'Biomass, periphyton, ash weight, grams per square meter',
#  'p00573': 'Biomass, periphyton, dry weight, grams per square meter',
#  'p00600': 'Total nitrogen [nitrate + nitrite + ammonia + organic-N], water, unfiltered, milligrams per liter',
#  'p00602': 'Total nitrogen [nitrate + nitrite + ammonia + organic-N], water, filtered, milligrams per liter',
#  'p00605': 'Organic nitrogen, water, unfiltered, milligrams per liter as nitrogen',
#  'p00607': 'Organic nitrogen, water, filtered, milligrams per liter as nitrogen',
#  'p00608': 'Ammonia (NH3 + NH4+), water, filtered, milligrams per liter as nitrogen',
#  'p00610': 'Ammonia (NH3 + NH4+), water, unfiltered, milligrams per liter as nitrogen',
#  'p00613': 'Nitrite, water, filtered, milligrams per liter as nitrogen',
#  'p00615': 'Nitrite, water, unfiltered, milligrams per liter as nitrogen',
#  'p00618': 'Nitrate, water, filtered, milligrams per liter as nitrogen',
#  'p00620': 'Nitrate, water, unfiltered, milligrams per liter as nitrogen',
#  'p00623': 'Ammonia plus organic nitrogen, water, filtered, milligrams per liter as nitrogen',
#  'p00624': 'Ammonia plus organic nitrogen, suspended sediment, total, milligrams per liter as nitrogen',
#  'p00625': 'Ammonia plus organic nitrogen, water, unfiltered, milligrams per liter as nitrogen',
#  'p00630': 'Nitrate plus nitrite, water, unfiltered, milligrams per liter as nitrogen',
#  'p00631': 'Nitrate plus nitrite, water, filtered, milligrams per liter as nitrogen',
#  'p00650': 'Phosphate, water, unfiltered, milligrams per liter as PO4',
#  'p00660': 'Orthophosphate, water, filtered, milligrams per liter as PO4',
#  'p00665': 'Phosphorus, water, unfiltered, milligrams per liter as phosphorus',
#  'p00666': 'Phosphorus, water, filtered, milligrams per liter as phosphorus',
#  'p00671': 'Orthophosphate, water, filtered, milligrams per liter as phosphorus',
#  'p00680': 'Organic carbon, water, unfiltered, milligrams per liter',
#  'p00681': 'Organic carbon, water, filtered, milligrams per liter',
#  'p00689': 'Organic carbon, suspended sediment, total, milligrams per liter',
#  'p00720': 'Cyanide, water, unfiltered, milligrams per liter',
#  'p00721': 'Cyanide, bed sediment, total, dry weight, milligrams per kilogram',
#  'p00745': 'Sulfide, water, unfiltered, milligrams per liter',
#  'p00746': 'Sulfide, water, filtered, milligrams per liter',
#  'p00900': 'Hardness, water, milligrams per liter as calcium carbonate',
#  'p00902': 'Noncarbonate hardness, water, unfiltered, field, milligrams per liter as calcium carbonate',
#  'p00904': 'Noncarbonate hardness, water, filtered, field, milligrams per liter as calcium carbonate',
#  'p00905': 'Noncarbonate hardness, water, filtered, lab, milligrams per liter as calcium carbonate',
#  'p00915': 'Calcium, water, filtered, milligrams per liter',
#  'p00925': 'Magnesium, water, filtered, milligrams per liter',
#  'p00930': 'Sodium, water, filtered, milligrams per liter',
#  'p00931': 'Sodium adsorption ratio (SAR), water, number',
#  'p00932': 'Sodium fraction of cations, water, percent in equivalents of major cations',
#  'p00933': 'Sodium plus potassium, water, filtered, milligrams per liter as sodium',
#  'p00935': 'Potassium, water, filtered, milligrams per liter',
#  'p00940': 'Chloride, water, filtered, milligrams per liter',
#  'p00945': 'Sulfate, water, filtered, milligrams per liter',
#  'p00950': 'Fluoride, water, filtered, milligrams per liter',
#  'p00955': 'Silica, water, filtered, milligrams per liter as SiO2',
#  'p01000': 'Arsenic, water, filtered, micrograms per liter',
#  'p01001': 'Arsenic, suspended sediment, total, micrograms per liter',
#  'p01002': 'Arsenic, water, unfiltered, micrograms per liter',
#  'p01003': 'Arsenic, bed sediment, total digestion, dry weight, milligrams per kilogram',
#  'p01005': 'Barium, water, filtered, micrograms per liter',
#  'p01006': 'Barium, suspended sediment, recoverable, micrograms per liter',
#  'p01007': 'Barium, water, unfiltered, recoverable, micrograms per liter',
#  'p01010': 'Beryllium, water, filtered, micrograms per liter',
#  'p01020': 'Boron, water, filtered, micrograms per liter',
#  'p01025': 'Cadmium, water, filtered, micrograms per liter',
#  'p01026': 'Cadmium, suspended sediment, recoverable, micrograms per liter',
#  'p01027': 'Cadmium, water, unfiltered, micrograms per liter',
#  'p01028': 'Cadmium, bed sediment, recoverable, dry weight, milligrams per kilogram',
#  'p01030': 'Chromium, water, filtered, micrograms per liter',
#  'p01031': 'Chromium, suspended sediment, recoverable, micrograms per liter',
#  'p01032': 'Chromium(VI), water, filtered, micrograms per liter as Cr',
#  'p01034': 'Chromium, water, unfiltered, recoverable, micrograms per liter',
#  'p01035': 'Cobalt, water, filtered, micrograms per liter',
#  'p01036': 'Cobalt, suspended sediment, recoverable, micrograms per liter',
#  'p01037': 'Cobalt, water, unfiltered, recoverable, micrograms per liter',
#  'p01040': 'Copper, water, filtered, micrograms per liter',
#  'p01041': 'Copper, suspended sediment, recoverable, micrograms per liter',
#  'p01042': 'Copper, water, unfiltered, recoverable, micrograms per liter',
#  'p01043': 'Copper, bed sediment, recoverable, dry weight, milligrams per kilogram',
#  'p01044': 'Iron, suspended sediment, recoverable, micrograms per liter',
#  'p01045': 'Iron, water, unfiltered, recoverable, micrograms per liter',
#  'p01046': 'Iron, water, filtered, micrograms per liter',
#  'p01047': 'Iron(II), water, filtered, micrograms per liter',
#  'p01048': 'Iron(II) plus Iron(III), water, filtered, micrograms per liter',
#  'p01049': 'Lead, water, filtered, micrograms per liter',
#  'p01050': 'Lead, suspended sediment, recoverable, micrograms per liter',
#  'p01051': 'Lead, water, unfiltered, recoverable, micrograms per liter',
#  'p01052': 'Lead, bed sediment, recoverable, dry weight, milligrams per kilogram',
#  'p01054': 'Manganese, suspended sediment, recoverable, micrograms per liter',
#  'p01055': 'Manganese, water, unfiltered, recoverable, micrograms per liter',
#  'p01056': 'Manganese, water, filtered, micrograms per liter',
#  'p01057': 'Thallium, water, filtered, micrograms per liter',
#  'p01060': 'Molybdenum, water, filtered, micrograms per liter',
#  'p01065': 'Nickel, water, filtered, micrograms per liter',
#  'p01066': 'Nickel, suspended sediment, recoverable, micrograms per liter',
#  'p01067': 'Nickel, water, unfiltered, recoverable, micrograms per liter',
#  'p01068': 'Nickel, bed sediment, recoverable, dry weight, milligrams per kilogram',
#  'p01075': 'Silver, water, filtered, micrograms per liter',
#  'p01076': 'Silver, suspended sediment, recoverable, micrograms per liter',
#  'p01077': 'Silver, water, unfiltered, recoverable, micrograms per liter',
#  'p01080': 'Strontium, water, filtered, micrograms per liter',
#  'p01085': 'Vanadium, water, filtered, micrograms per liter',
#  'p01090': 'Zinc, water, filtered, micrograms per liter',
#  'p01091': 'Zinc, suspended sediment, recoverable, micrograms per liter',
#  'p01092': 'Zinc, water, unfiltered, recoverable, micrograms per liter',
#  'p01093': 'Zinc, bed sediment, recoverable, dry weight, milligrams per kilogram',
#  'p01095': 'Antimony, water, filtered, micrograms per liter',
#  'p01105': 'Aluminum, water, unfiltered, recoverable, micrograms per liter',
#  'p01106': 'Aluminum, water, filtered, micrograms per liter',
#  'p01130': 'Lithium, water, filtered, micrograms per liter',
#  'p01145': 'Selenium, water, filtered, micrograms per liter',
#  'p01146': 'Selenium, suspended sediment, total, micrograms per liter',
#  'p01147': 'Selenium, water, unfiltered, micrograms per liter',
#  'p01148': 'Selenium, bed sediment, total digestion, dry weight, milligrams per kilogram',
#  'p01155': 'Tungsten, water, filtered, micrograms per liter',
#  'p01170': 'Iron, bed sediment, total digestion, dry weight, milligrams per kilogram',
#  'p04022': 'Terbuthylazine, water, filtered, recoverable, micrograms per liter',
#  'p04024': 'Propachlor, water, filtered, recoverable, micrograms per liter',
#  'p04025': 'Hexazinone, water, filtered, recoverable, micrograms per liter',
#  'p04028': 'Butylate, water, filtered, recoverable, micrograms per liter',
#  'p04029': 'Bromacil, water, filtered, recoverable, micrograms per liter',
#  'p04031': 'Cycloate, water, filtered, recoverable, micrograms per liter',
#  'p04032': 'Terbacil, water, filtered, recoverable, micrograms per liter',
#  'p04033': 'Diphenamid, water, filtered, recoverable, micrograms per liter',
#  'p04035': 'Simazine, water, filtered, recoverable, micrograms per liter',
#  'p04036': 'Prometryn, water, filtered, recoverable, micrograms per liter',
#  'p04037': 'Prometon, water, filtered, recoverable, micrograms per liter',
#  'p04038': '2-Chloro-6-ethylamino-4-amino-s-triazine, water, filtered, recoverable, micrograms per liter',
#  'p04040': '2-Chloro-4-isopropylamino-6-amino-s-triazine, water, filtered, recoverable, micrograms per liter',
#  'p04041': 'Cyanazine, water, filtered, recoverable, micrograms per liter',
#  'p04095': 'Fonofos, water, filtered, recoverable, micrograms per liter',
#  'p04254': 'Metalaxyl, water, unfiltered, recoverable, micrograms per liter',
#  'p07000': 'Tritium, water, unfiltered, picocuries per liter',
#  'p07012': 'Tritium in water molecules, tritium units',
#  'p07013': 'Tritium in water molecules counting error, tritium units',
#  'p09503': 'Radium-226, water, filtered, picocuries per liter',
#  'p09511': 'Radium-226, water, filtered, radon method, picocuries per liter',
#  'p22603': 'Uranium-238, water, filtered, picocuries per liter',
#  'p22610': 'Uranium-234, water, filtered, picocuries per liter',
#  'p22620': 'Uranium-235, water, filtered, picocuries per liter',
#  'p22703': 'Uranium (natural), water, filtered, micrograms per liter',
#  'p29801': 'Alkalinity, water, filtered, fixed endpoint (pH 4.5) titration, laboratory, milligrams per liter as calcium carbonate',
#  'p29802': 'Alkalinity, water, filtered, Gran titration, field, milligrams per liter as calcium carbonate',
#  'p29804': 'Bicarbonate, water, filtered, fixed endpoint (pH 4.5) titration, field, milligrams per liter',
#  'p29807': 'Carbonate, water, filtered, fixed endpoint (pH 8.3) titration, field, milligrams per liter',
#  'p30194': '2-Methylnaphthalene, water, unfiltered, recoverable, micrograms per liter',
#  'p30195': '2-Nitroaniline, water, unfiltered, recoverable, micrograms per liter',
#  'p30196': '4-Nitroaniline, water, unfiltered, recoverable, micrograms per liter',
#  'p30204': '2-Methyl-4,6-dinitrophenol, water, unfiltered, recoverable, micrograms per liter',
#  'p30207': 'Gage height, above datum, meters',
#  'p30208': 'Discharge, cubic meters per second',
#  'p30209': 'Discharge, instantaneous, cubic meters per second',
#  'p30210': 'Depth to water level, below land surface datum (LSD), meters',
#  'p30217': 'Dibromomethane, water, unfiltered, recoverable, micrograms per liter',
#  'p30218': 'Dichlorvos, water, unfiltered, recoverable, micrograms per liter',
#  'p30234': 'Bromacil, water, unfiltered, recoverable, micrograms per liter',
#  'p30241': 'Inorganic carbon, bed sediment, dry weight, percent',
#  'p30243': 'Organic carbon, bed sediment, dry weight, percent',
#  'p30343': '4-Chloroaniline, water, unfiltered, recoverable, micrograms per liter',
#  'p31501': 'Total coliforms, M-Endo MF method, immediate, water, colony forming units per 100 milliliters',
#  'p31503': 'Total coliforms, M-Endo MF method, delayed, water, colonies per 100 milliliters',
#  'p31616': 'Fecal coliforms, M-FC MF (0.45 micron) method, water, colony forming units per 100 milliliters',
#  'p31625': 'Fecal coliforms, M-FC MF (0.7 micron) method, water, colony forming units per 100 milliliters',
#  'p31673': 'Fecal streptococci, KF streptococcus MF method, water, colony forming units per 100 milliliters',
#  'p31679': 'Fecal streptococci, m-Enterococcus MF method, water, colonies per 100 milliliters',
#  'p32002': 'Sample volume, milliliters',
#  'p32101': 'Bromodichloromethane, water, unfiltered, recoverable, micrograms per liter',
#  'p32102': 'Tetrachloromethane, water, unfiltered, recoverable, micrograms per liter',
#  'p32103': '1,2-Dichloroethane, water, unfiltered, recoverable, micrograms per liter',
#  'p32104': 'Tribromomethane, water, unfiltered, recoverable, micrograms per liter',
#  'p32105': 'Dibromochloromethane, water, unfiltered, recoverable, micrograms per liter',
#  'p32106': 'Trichloromethane, water, unfiltered, recoverable, micrograms per liter',
#  'p32730': 'Phenolic compounds, water, unfiltered, recoverable, micrograms per liter',
#  'p34010': 'Toluene, water, unfiltered, recoverable, micrograms per liter',
#  'p34030': 'Benzene, water, unfiltered, recoverable, micrograms per liter',
#  'p34200': 'Acenaphthylene, water, unfiltered, recoverable, micrograms per liter',
#  'p34205': 'Acenaphthene, water, unfiltered, recoverable, micrograms per liter',
#  'p34215': 'Acrylonitrile, water, unfiltered, recoverable, micrograms per liter',
#  'p34220': 'Anthracene, water, unfiltered, recoverable, micrograms per liter',
#  'p34230': 'Benzo[b]fluoranthene, water, unfiltered, recoverable, micrograms per liter',
#  'p34242': 'Benzo[k]fluoranthene, water, unfiltered, recoverable, micrograms per liter',
#  'p34247': 'Benzo[a]pyrene, water, unfiltered, recoverable, micrograms per liter',
#  'p34253': 'alpha-HCH, water, filtered, recoverable, micrograms per liter',
#  'p34273': 'Bis(2-chloroethyl) ether, water, unfiltered, recoverable, micrograms per liter',
#  'p34278': 'Bis(2-chloroethoxy)methane, water, unfiltered, recoverable, micrograms per liter',
#  'p34283': 'Bis(2-chloroisopropyl) ether, water, unfiltered, recoverable, micrograms per liter',
#  'p34292': 'Benzyl n-butyl phthalate, water, unfiltered, recoverable, micrograms per liter',
#  'p34301': 'Chlorobenzene, water, unfiltered, recoverable, micrograms per liter',
#  'p34311': 'Chloroethane, water, unfiltered, recoverable, micrograms per liter',
#  'p34320': 'Chrysene, water, unfiltered, recoverable, micrograms per liter',
#  'p34336': 'Diethyl phthalate, water, unfiltered, recoverable, micrograms per liter',
#  'p34341': 'Dimethyl phthalate, water, unfiltered, recoverable, micrograms per liter',
#  'p34362': 'alpha-Endosulfan, water, filtered, recoverable, micrograms per liter',
#  'p34371': 'Ethylbenzene, water, unfiltered, recoverable, micrograms per liter',
#  'p34376': 'Fluoranthene, water, unfiltered, recoverable, micrograms per liter',
#  'p34381': '9H-Fluorene, water, unfiltered, recoverable, micrograms per liter',
#  'p34386': 'Hexachlorocyclopentadiene, water, unfiltered, recoverable, micrograms per liter',
#  'p34391': 'Hexachlorobutadiene, water, unfiltered, recoverable, micrograms per liter',
#  'p34396': 'Hexachloroethane, water, unfiltered, recoverable, micrograms per liter',
#  'p34403': 'Indeno[1,2,3-cd]pyrene, water, unfiltered, recoverable, micrograms per liter',
#  'p34408': 'Isophorone, water, unfiltered, recoverable, micrograms per liter',
#  'p34413': 'Bromomethane, water, unfiltered, recoverable, micrograms per liter',
#  'p34418': 'Chloromethane, water, unfiltered, recoverable, micrograms per liter',
#  'p34423': 'Dichloromethane, water, unfiltered, recoverable, micrograms per liter',
#  'p34428': 'N-Nitrosodi-n-propylamine, water, unfiltered, recoverable, micrograms per liter',
#  'p34433': 'N-Nitrosodiphenylamine, water, unfiltered, recoverable, micrograms per liter',
#  'p34438': 'N-Nitrosodimethylamine (NDMA), water, unfiltered, recoverable, micrograms per liter',
#  'p34447': 'Nitrobenzene, water, unfiltered, recoverable, micrograms per liter',
#  'p34452': '4-Chloro-3-methylphenol, water, unfiltered, recoverable, micrograms per liter',
#  'p34461': 'Phenanthrene, water, unfiltered, recoverable, micrograms per liter',
#  'p34469': 'Pyrene, water, unfiltered, recoverable, micrograms per liter',
#  'p34475': 'Tetrachloroethene, water, unfiltered, recoverable, micrograms per liter',
#  'p34488': 'Trichlorofluoromethane, water, unfiltered, recoverable, micrograms per liter',
#  'p34496': '1,1-Dichloroethane, water, unfiltered, recoverable, micrograms per liter',
#  'p34501': '1,1-Dichloroethene, water, unfiltered, recoverable, micrograms per liter',
#  'p34506': '1,1,1-Trichloroethane, water, unfiltered, recoverable, micrograms per liter',
#  'p34511': '1,1,2-Trichloroethane, water, unfiltered, recoverable, micrograms per liter',
#  'p34516': '1,1,2,2-Tetrachloroethane, water, unfiltered, recoverable, micrograms per liter',
#  'p34521': 'Benzo[ghi]perylene, water, unfiltered, recoverable, micrograms per liter',
#  'p34526': 'Benzo[a]anthracene, water, unfiltered, recoverable, micrograms per liter',
#  'p34536': '1,2-Dichlorobenzene, water, unfiltered, recoverable, micrograms per liter',
#  'p34541': '1,2-Dichloropropane, water, unfiltered, recoverable, micrograms per liter',
#  'p34546': 'trans-1,2-Dichloroethene, water, unfiltered, recoverable, micrograms per liter',
#  'p34551': '1,2,4-Trichlorobenzene, water, unfiltered, recoverable, micrograms per liter',
#  'p34556': 'Dibenzo[a,h]anthracene, water, unfiltered, recoverable, micrograms per liter',
#  'p34561': '1,3-Dichloropropene, water, unfiltered, recoverable, micrograms per liter',
#  'p34566': '1,3-Dichlorobenzene, water, unfiltered, recoverable, micrograms per liter',
#  'p34571': '1,4-Dichlorobenzene, water, unfiltered, recoverable, micrograms per liter',
#  'p34576': '2-Chloroethyl vinyl ether, water, unfiltered, recoverable, micrograms per liter',
#  'p34581': '2-Chloronaphthalene, water, unfiltered, recoverable, micrograms per liter',
#  'p34586': '2-Chlorophenol, water, unfiltered, recoverable, micrograms per liter',
#  'p34591': '2-Nitrophenol, water, unfiltered, recoverable, micrograms per liter',
#  'p34596': 'Di-n-octyl phthalate, water, unfiltered, recoverable, micrograms per liter',
#  'p34601': '2,4-Dichlorophenol, water, unfiltered, recoverable, micrograms per liter',
#  'p34606': '2,4-Dimethylphenol, water, unfiltered, recoverable, micrograms per liter',
#  'p34611': '2,4-Dinitrotoluene, water, unfiltered, recoverable, micrograms per liter',
#  'p34616': '2,4-Dinitrophenol, water, unfiltered, recoverable, micrograms per liter',
#  'p34621': '2,4,6-Trichlorophenol, water, unfiltered, recoverable, micrograms per liter',
#  'p34626': '2,6-Dinitrotoluene, water, unfiltered, recoverable, micrograms per liter',
#  'p34631': "3,3'-Dichlorobenzidine, water, unfiltered, recoverable, micrograms per liter",
#  'p34636': '4-Bromophenyl phenyl ether, water, unfiltered, recoverable, micrograms per liter',
#  'p34641': '4-Chlorophenyl phenyl ether, water, unfiltered, recoverable, micrograms per liter',
#  'p34646': '4-Nitrophenol, water, unfiltered, recoverable, micrograms per liter',
#  'p34653': "p,p'-DDE, water, filtered, recoverable, micrograms per liter",
#  'p34657': '2-Methyl-4,6-dinitrophenol, water, unfiltered, recoverable, micrograms per liter',
#  'p34668': 'Dichlorodifluoromethane, water, unfiltered, recoverable, micrograms per liter',
#  'p34694': 'Phenol, water, unfiltered, recoverable, micrograms per liter',
#  'p34696': 'Naphthalene, water, unfiltered, recoverable, micrograms per liter',
#  'p34699': 'trans-1,3-Dichloropropene, water, unfiltered, recoverable, micrograms per liter',
#  'p34704': 'cis-1,3-Dichloropropene, water, unfiltered, recoverable, micrograms per liter',
#  'p38260': 'Methylene blue active substances, water, unfiltered, recoverable, milligrams per liter',
#  'p38442': 'Dicamba, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p38454': 'Dicrotophos, water, filtered, recoverable, micrograms per liter',
#  'p38478': 'Linuron, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p38482': 'MCPA, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p38487': 'MCPB, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p38501': 'Methiocarb, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p38538': 'Propoxur, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p38548': 'Siduron, water, filtered, recoverable, micrograms per liter',
#  'p38711': 'Bentazon, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p38746': '2,4-DB, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p38775': 'Dichlorvos, water, filtered, recoverable, micrograms per liter',
#  'p38811': 'Fluometuron, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p38866': 'Oxamyl, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p38932': 'Chlorpyrifos, water, unfiltered, recoverable, micrograms per liter',
#  'p38933': 'Chlorpyrifos, water, filtered, recoverable, micrograms per liter',
#  'p39024': 'Propazine, water, unfiltered, recoverable, micrograms per liter',
#  'p39030': 'Trifluralin, water, unfiltered, recoverable, micrograms per liter',
#  'p39032': 'Pentachlorophenol, water, unfiltered, recoverable, micrograms per liter',
#  'p39036': 'Alkalinity, water, filtered, fixed endpoint (pH 4.5) titration, field, milligrams per liter as calcium carbonate',
#  'p39054': 'Simetryn, water, unfiltered, recoverable, micrograms per liter',
#  'p39055': 'Simazine, water, unfiltered, recoverable, micrograms per liter',
#  'p39056': 'Prometon, water, unfiltered, recoverable, micrograms per liter',
#  'p39057': 'Prometryn, water, unfiltered, recoverable, micrograms per liter',
#  'p39086': 'Alkalinity, water, filtered, inflection-point titration method (incremental titration method), field, milligrams per liter as calcium carbonate',
#  'p39100': 'Bis(2-ethylhexyl) phthalate, water, unfiltered, recoverable, micrograms per liter',
#  'p39110': 'Di-n-butyl phthalate, water, unfiltered, recoverable, micrograms per liter',
#  'p39175': 'Vinyl chloride, water, unfiltered, recoverable, micrograms per liter',
#  'p39180': 'Trichloroethene, water, unfiltered, recoverable, micrograms per liter',
#  'p39250': 'Polychlorinated naphthalenes, water, unfiltered, recoverable, micrograms per liter',
#  'p39251': 'Polychlorinated naphthalenes, bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39330': 'Aldrin, water, unfiltered, recoverable, micrograms per liter',
#  'p39333': 'Aldrin, bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39340': 'Lindane, water, unfiltered, recoverable, micrograms per liter',
#  'p39341': 'Lindane, water, filtered, recoverable, micrograms per liter',
#  'p39343': 'Lindane, bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39350': 'Chlordane (technical), water, unfiltered, recoverable, micrograms per liter',
#  'p39351': 'Chlordane (technical), bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39360': "p,p'-DDD, water, unfiltered, recoverable, micrograms per liter",
#  'p39363': "p,p'-DDD, bed sediment, recoverable, dry weight, micrograms per kilogram",
#  'p39365': "p,p'-DDE, water, unfiltered, recoverable, micrograms per liter",
#  'p39368': "p,p'-DDE, bed sediment, recoverable, dry weight, micrograms per kilogram",
#  'p39370': "p,p'-DDT, water, unfiltered, recoverable, micrograms per liter",
#  'p39373': "p,p'-DDT, bed sediment, recoverable, dry weight, micrograms per kilogram",
#  'p39380': 'Dieldrin, water, unfiltered, recoverable, micrograms per liter',
#  'p39381': 'Dieldrin, water, filtered, recoverable, micrograms per liter',
#  'p39383': 'Dieldrin, bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39388': 'alpha-Endosulfan, water, unfiltered, recoverable, micrograms per liter',
#  'p39389': 'alpha-Endosulfan, bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39390': 'Endrin, water, unfiltered, recoverable, micrograms per liter',
#  'p39393': 'Endrin, bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39398': 'Ethion, water, unfiltered, recoverable, micrograms per liter',
#  'p39400': 'Toxaphene, water, unfiltered, recoverable, micrograms per liter',
#  'p39403': 'Toxaphene, bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39410': 'Heptachlor, water, unfiltered, recoverable, micrograms per liter',
#  'p39413': 'Heptachlor, bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39415': 'Metolachlor, water, filtered, recoverable, micrograms per liter',
#  'p39420': 'Heptachlor epoxide, water, unfiltered, recoverable, micrograms per liter',
#  'p39423': 'Heptachlor epoxide, bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39481': "p,p'-Methoxychlor, bed sediment, recoverable, dry weight, micrograms per kilogram",
#  'p39516': 'PCBs, water, unfiltered, recoverable, micrograms per liter',
#  'p39519': 'PCBs, bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39530': 'Malathion, water, unfiltered, recoverable, micrograms per liter',
#  'p39532': 'Malathion, water, filtered, recoverable, micrograms per liter',
#  'p39540': 'Parathion, water, unfiltered, recoverable, micrograms per liter',
#  'p39542': 'Parathion, water, filtered, recoverable, micrograms per liter',
#  'p39570': 'Diazinon, water, unfiltered, recoverable, micrograms per liter',
#  'p39572': 'Diazinon, water, filtered, recoverable, micrograms per liter',
#  'p39600': 'Methyl parathion, water, unfiltered, recoverable, micrograms per liter',
#  'p39630': 'Atrazine, water, unfiltered, recoverable, micrograms per liter',
#  'p39632': 'Atrazine, water, filtered, recoverable, micrograms per liter',
#  'p39700': 'Hexachlorobenzene, water, unfiltered, recoverable, micrograms per liter',
#  'p39702': 'Hexachlorobutadiene, water, unfiltered, recoverable, micrograms per liter',
#  'p39730': '2,4-D, water, unfiltered, recoverable, micrograms per liter',
#  'p39732': '2,4-D, water, filtered, recoverable, micrograms per liter',
#  'p39740': '2,4,5-T, water, unfiltered, recoverable, micrograms per liter',
#  'p39742': '2,4,5-T, water, filtered, recoverable, micrograms per liter',
#  'p39750': 'Carbaryl, water, unfiltered, recoverable, micrograms per liter',
#  'p39758': 'Mirex, bed sediment, recoverable, dry weight, micrograms per kilogram',
#  'p39760': 'Silvex, water, unfiltered, recoverable, micrograms per liter',
#  'p39762': 'Silvex, water, filtered, recoverable, micrograms per liter',
#  'p39786': 'Carbophenothion, water, unfiltered, recoverable, micrograms per liter',
#  'p39790': 'Methyl trithion, water, unfiltered, recoverable, micrograms per liter',
#  'p45013': 'Isopropyl acetate, water, unfiltered, recoverable, micrograms per liter',
#  'p45028': 'Chlorodifluoromethane, water, unfiltered, recoverable, micrograms per liter',
#  'p46342': 'Alachlor, water, filtered, recoverable, micrograms per liter',
#  'p46529': 'Precipitation, inches',
#  'p49235': 'Triclopyr, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49236': 'Propham, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49260': 'Acetochlor, water, filtered, recoverable, micrograms per liter',
#  'p49291': 'Picloram, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49292': 'Oryzalin, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49293': 'Norflurazon, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49294': 'Neburon, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49295': '1-Naphthol, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49296': 'Methomyl, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49297': 'Fenuron, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49299': '2-Methyl-4,6-dinitrophenol, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49300': 'Diuron, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49301': 'Dinoseb, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49302': 'Dichlorprop, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49303': 'Dichlobenil, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49304': 'DCPA monoacid, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49305': 'Clopyralid, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49306': 'Chlorothalonil, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49308': '3-Hydroxy carbofuran, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49309': 'Carbofuran, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49310': 'Carbaryl, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49311': 'Bromoxynil, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49312': 'Aldicarb, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49313': 'Aldicarb sulfone, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49314': 'Aldicarb sulfoxide, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49315': 'Acifluorfen, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p49538': '1,1-Difluoroethane, water, unfiltered, recoverable, micrograms per liter',
#  'p49932': 'delta sulfur-34/sulfur-32 of sulfate, water, filtered, per mil',
#  'p49933': 'Carbon-14, water, filtered, percent modern',
#  'p49934': 'Carbon-14 counting error, water, filtered, percent modern',
#  'p49954': 'Biomass, periphyton, ash free dry mass, grams per square meter',
#  'p49991': 'Methyl acrylate, water, unfiltered, recoverable, micrograms per liter',
#  'p49999': '1,2,3,4-Tetramethylbenzene, water, unfiltered, recoverable, micrograms per liter',
#  'p50000': '1,2,3,5-Tetramethylbenzene, water, unfiltered, recoverable, micrograms per liter',
#  'p50002': 'Bromoethene, water, unfiltered, recoverable, micrograms per liter',
#  'p50004': 'tert-Butyl ethyl ether, water, unfiltered, recoverable, micrograms per liter',
#  'p50005': 'Methyl tert-pentyl ether, water, unfiltered, recoverable, micrograms per liter',
#  'p50060': 'Chlorine (total residual), water, unfiltered, milligrams per liter',
#  'p50280': 'Site visit purpose, code',
#  'p50281': 'Trichlorofluoromethane, for age dating, water, unfiltered, recoverable, picograms per kilogram',
#  'p50282': 'Dichlorodifluoromethane, for age dating, water, unfiltered, recoverable, picograms per kilogram',
#  'p50283': '1,1,2-Trichloro-1,2,2-trifluoroethane, for age dating, water, unfiltered, recoverable, picograms per kilogram',
#  'p50299': 'Bendiocarb, water, filtered, recoverable, micrograms per liter',
#  'p50300': 'Benomyl, water, filtered, recoverable, micrograms per liter',
#  'p50305': 'Caffeine, water, filtered, recoverable, micrograms per liter',
#  'p50306': 'Chlorimuron-ethyl, water, filtered, recoverable, micrograms per liter',
#  'p50337': 'Sulfometuron-methyl, water, filtered, recoverable, micrograms per liter',
#  'p50355': '2-Hydroxy-4-isopropylamino-6-ethylamino-s-triazine, water, filtered, recoverable, micrograms per liter',
#  'p50356': 'Imazaquin, water, filtered, recoverable, micrograms per liter',
#  'p50359': 'Metalaxyl, water, filtered, recoverable, micrograms per liter',
#  'p50364': 'Nicosulfuron, water, filtered, recoverable, micrograms per liter',
#  'p50407': 'Imazethapyr, water, filtered, recoverable, micrograms per liter',
#  'p50468': 'Escherichia coli, defined substrate test method (DSTM), water, most probable number per 100 milliliters',
#  'p50470': '2,4-D methyl ester, water, filtered, recoverable, micrograms per liter',
#  'p50471': 'Propiconazole, water, filtered, recoverable, micrograms per liter',
#  'p50569': 'Total coliforms, defined substrate test method (DSTM), water, most probable number per 100 milliliters',
#  'p50624': 'Absorbance, 254 nm, water, filtered, absorbance units per centimeter',
#  'p50833': 'Radium-224, water, filtered, picocuries per liter',
#  'p50985': '1,2-Dichloro-1,1,2,2-tetrafluoroethane, water, unfiltered, recoverable, micrograms per liter',
#  'p51188': 'Helium, water, dissolved, mole percent of dissolved gases',
#  'p51189': 'Hydrogen, water, dissolved, mole percent of dissolved gases',
#  'p51190': 'Argon, water, dissolved, mole percent of dissolved gases',
#  'p51191': 'Oxygen, water, dissolved, mole percent of dissolved gases',
#  'p51192': 'Carbon dioxide, water, dissolved, mole percent of dissolved gases',
#  'p51193': 'Dinitrogen, water, dissolved, mole percent of dissolved gases',
#  'p51194': 'Carbon monoxide, water, dissolved, mole percent of dissolved gases',
#  'p51195': 'Propene, water, dissolved, mole percent of dissolved gases',
#  'p51196': 'C6 and higher-molecular-weight hydrocarbons, water, dissolved, mole percent of dissolved gases',
#  'p60050': 'Phytoplankton, total, cells per milliliter',
#  'p61028': 'Turbidity, water, unfiltered, field, nephelometric turbidity units',
#  'p61040': 'Helium-3/helium-4 ratio, water, unfiltered, ratio',
#  'p61046': 'Neon, water, unfiltered, cubic centimeters per gram at standard temperature and pressure',
#  'p61047': 'Neon error, water, unfiltered, cubic centimeters per gram at standard temperature and pressure',
#  'p61159': 'Tribenuron-methyl, water, filtered, recoverable, micrograms per liter',
#  'p61188': 'Chloramben methyl ester, water, filtered, recoverable, micrograms per liter',
#  'p61209': 'Perchlorate, water, unfiltered, micrograms per liter',
#  'p61585': 'Cyfluthrin, water, filtered, recoverable, micrograms per liter',
#  'p61586': 'Cypermethrin, water, filtered, recoverable, micrograms per liter',
#  'p61590': 'Endosulfan sulfate, water, filtered, recoverable, micrograms per liter',
#  'p61591': 'Fenamiphos, water, filtered, recoverable, micrograms per liter',
#  'p61593': 'Iprodione, water, filtered, recoverable, micrograms per liter',
#  'p61594': 'Isofenphos, water, filtered, recoverable, micrograms per liter',
#  'p61595': 'lambda-Cyhalothrin, water, filtered, recoverable, micrograms per liter',
#  'p61596': 'Metalaxyl, water, filtered, recoverable, micrograms per liter',
#  'p61598': 'Methidathion, water, filtered, recoverable, micrograms per liter',
#  'p61599': 'Myclobutanil, water, filtered, recoverable, micrograms per liter',
#  'p61600': 'Oxyfluorfen, water, filtered, recoverable, micrograms per liter',
#  'p61601': 'Phosmet, water, filtered, recoverable, micrograms per liter',
#  'p61606': 'Tefluthrin, water, filtered, recoverable, micrograms per liter',
#  'p61610': 'Tribufos, water, filtered, recoverable, micrograms per liter',
#  'p61618': "2-Chloro-2',6'-diethylacetanilide, water, filtered, recoverable, micrograms per liter",
#  'p61620': '2-Ethyl-6-methylaniline, water, filtered, recoverable, micrograms per liter',
#  'p61625': '3,4-Dichloroaniline, water, filtered, recoverable, micrograms per liter',
#  'p61627': '3,5-Dichloroaniline, water, filtered, recoverable, micrograms per liter',
#  'p61633': '4-Chloro-2-methylphenol, water, filtered, recoverable, micrograms per liter',
#  'p61635': 'Azinphos-methyl oxygen analog, water, filtered, recoverable, micrograms per liter',
#  'p61636': 'Chlorpyrifos oxygen analog, water, filtered, recoverable, micrograms per liter',
#  'p61638': 'Diazoxon, water, filtered, recoverable, micrograms per liter',
#  'p61640': 'Disulfoton sulfone, water, filtered, recoverable, micrograms per liter',
#  'p61644': 'Ethion monoxon, water, filtered, recoverable, micrograms per liter',
#  'p61645': 'Fenamiphos sulfone, water, filtered, recoverable, micrograms per liter',
#  'p61646': 'Fenamiphos sulfoxide, water, filtered, recoverable, micrograms per liter',
#  'p61652': 'Malaoxon, water, filtered, recoverable, micrograms per liter',
#  'p61664': 'Methyl paraoxon, water, filtered, recoverable, micrograms per liter',
#  'p61666': 'Phorate oxygen analog, water, filtered, recoverable, micrograms per liter',
#  'p61668': 'Phosmet oxygen analog, water, filtered, recoverable, micrograms per liter',
#  'p61674': 'Terbufos oxygen analog sulfone, water, filtered, recoverable, micrograms per liter',
#  'p61692': "N-(4-Chlorophenyl)-N'-methylurea, water, filtered, recoverable, micrograms per liter",
#  'p61693': 'Bensulfuron-methyl, water, filtered, recoverable, micrograms per liter',
#  'p61694': 'Flumetsulam, water, filtered, recoverable, micrograms per liter',
#  'p61695': 'Imidacloprid, water, filtered, recoverable, micrograms per liter',
#  'p61697': 'Metsulfuron-methyl, water, filtered, recoverable, micrograms per liter',
#  'p61702': '3-tert-Butyl-4-hydroxyanisole, water, unfiltered, recoverable, micrograms per liter',
#  'p61703': '4-Nonylphenol diethoxylate (sum of all isomers), water, unfiltered, recoverable, micrograms per liter',
#  'p61704': '4-Nonylphenol monoethoxylate (sum of all isomers), water, unfiltered, recoverable, micrograms per liter',
#  'p61707': 'Tris(dichloroisopropyl) phosphate, water, unfiltered, recoverable, micrograms per liter',
#  'p61708': 'Triclosan, water, unfiltered, recoverable, micrograms per liter',
#  'p61726': 'Absorbance, UV, organic constituents, 280 nm, 1 cm path length, water, filtered, absorbance units per centimeter',
#  'p61944': '5-Methyl-1H-benzotriazole, water, unfiltered, recoverable, micrograms per liter',
#  'p61945': 'Cotinine, water, unfiltered, recoverable, micrograms per liter',
#  'p61947': 'N,N-Diethyl-m-toluamide (DEET), water, unfiltered, recoverable, micrograms per liter',
#  'p61948': 'beta-Stigmastanol, water, unfiltered, recoverable, micrograms per liter',
#  'p62000': 'Acetaminophen, water, filtered, recoverable, micrograms per liter',
#  'p62003': 'Codeine, water, filtered, recoverable, micrograms per liter',
#  'p62004': 'Dehydronifedipine, water, filtered, recoverable, micrograms per liter',
#  'p62005': 'Cotinine, water, filtered, recoverable, micrograms per liter',
#  'p62008': 'Diltiazem, water, filtered, recoverable, micrograms per liter',
#  'p62020': 'Albuterol, water, filtered, recoverable, micrograms per liter',
#  'p62021': 'Sulfamethoxazole, water, filtered, recoverable, micrograms per liter',
#  'p62023': 'Trimethoprim, water, filtered, recoverable, micrograms per liter',
#  'p62024': 'Warfarin, water, filtered, recoverable, micrograms per liter',
#  'p62030': '1,7-Dimethylxanthine, water, filtered, recoverable, micrograms per liter',
#  'p62166': 'Fipronil, water, filtered, recoverable, micrograms per liter',
#  'p62167': 'Fipronil sulfide, water, filtered, recoverable, micrograms per liter',
#  'p62168': 'Fipronil sulfone, water, filtered, recoverable, micrograms per liter',
#  'p62169': 'Desulfinylfipronil amide, water, filtered, recoverable, micrograms per liter',
#  'p62170': 'Desulfinylfipronil, water, filtered, recoverable, micrograms per liter',
#  'p62174': '2,2-Dichloro-1,1,1-trifluoroethane, water, unfiltered, recoverable, micrograms per liter',
#  'p62360': 'Pheophytin a, phytoplankton, micrograms per liter',
#  'p62452': 'Arsenite, water, filtered, micrograms per liter as arsenic',
#  'p62463': 'Carbon [inorganic plus organic], bed sediment, dry weight, percent',
#  'p62485': '4-tert-Octylphenol monoethoxylate, water, unfiltered, recoverable, micrograms per liter',
#  'p62486': '4-tert-Octylphenol diethoxylate, water, unfiltered, recoverable, micrograms per liter',
#  'p62636': 'Gross alpha radioactivity, 72 hour count, water, filtered, Th-230 curve, picocuries per liter',
#  'p62639': 'Gross alpha radioactivity, 30 day count, water, filtered, Th-230 curve, picocuries per liter',
#  'p62642': 'Gross beta radioactivity, 72 hour count, water, filtered, Cs-137 curve, picocuries per liter',
#  'p62645': 'Gross beta radioactivity, 30 day count, water, filtered, Cs-137 curve, picocuries per liter',
#  'p62648': 'delta boron-11/boron-10, water, filtered, per mil',
#  'p62793': 'Carbamazepine, water, filtered, recoverable, micrograms per liter',
#  'p62796': 'Diphenhydramine, water, filtered, recoverable, micrograms per liter',
#  'p62801': 'Thiabendazole, water, filtered, recoverable, micrograms per liter',
#  'p62805': '2,6-Dimethylnaphthalene, water, unfiltered, recoverable, micrograms per liter',
#  'p62806': '3-beta-Coprostanol, water, unfiltered, recoverable, micrograms per liter',
#  'p62807': '3-Methyl-1H-indole, water, unfiltered, recoverable, micrograms per liter',
#  'p62808': '4-Cumylphenol, water, unfiltered, recoverable, micrograms per liter',
#  'p62809': '4-n-Octylphenol, water, unfiltered, recoverable, micrograms per liter',
#  'p62810': '4-tert-Octylphenol, water, unfiltered, recoverable, micrograms per liter',
#  'p62811': 'Acetophenone, water, unfiltered, recoverable, micrograms per liter',
#  'p62812': 'Acetyl hexamethyl tetrahydro naphthalene, water, unfiltered, recoverable, micrograms per liter',
#  'p62813': '9,10-Anthraquinone, water, unfiltered, recoverable, micrograms per liter',
#  'p62814': 'Benzophenone, water, unfiltered, recoverable, micrograms per liter',
#  'p62815': 'beta-Sitosterol, water, unfiltered, recoverable, micrograms per liter',
#  'p62816': 'Bisphenol A, water, unfiltered, recoverable, micrograms per liter',
#  'p62817': 'Camphor, water, unfiltered, recoverable, micrograms per liter',
#  'p62818': 'Cholesterol, water, unfiltered, recoverable, micrograms per liter',
#  'p62819': 'D-Limonene, water, unfiltered, recoverable, micrograms per liter',
#  'p62823': 'Hexahydrohexamethyl cyclopentabenzopyran, water, unfiltered, recoverable, micrograms per liter',
#  'p62824': 'Indole, water, unfiltered, recoverable, micrograms per liter',
#  'p62825': 'Isoborneol, water, unfiltered, recoverable, micrograms per liter',
#  'p62826': 'Isoquinoline, water, unfiltered, recoverable, micrograms per liter',
#  'p62827': 'Menthol, water, unfiltered, recoverable, micrograms per liter',
#  'p62828': 'Methyl salicylate, water, unfiltered, recoverable, micrograms per liter',
#  'p62829': '4-Nonylphenol (sum of all isomers), water, unfiltered, recoverable, micrograms per liter',
#  'p62830': 'Tris(2-butoxyethyl) phosphate, water, unfiltered, recoverable, micrograms per liter',
#  'p62831': 'Tris(2-chloroethyl) phosphate, water, unfiltered, recoverable, micrograms per liter',
#  'p62832': 'Tributyl phosphate, water, unfiltered, recoverable, micrograms per liter',
#  'p62833': 'Triethyl citrate, water, unfiltered, recoverable, micrograms per liter',
#  'p62834': 'Triphenyl phosphate, water, unfiltered, recoverable, micrograms per liter',
#  'p62835': 'Isobutyl alcohol-d6, surrogate, water, unfiltered, percent recovery',
#  'p62839': 'Bisphenol A-d3, surrogate, NWQL schedule 4433 and labcode 8033 (WWWW), water, unfiltered, percent recovery',
#  'p62840': 'Caffeine-13C, surrogate, NWQL schedule 4433 and labcode 8033 (WWWW), water, unfiltered, percent recovery',
#  'p62841': 'Decafluorobiphenyl, surrogate, NWQL schedule 4433 and labcode 8033 (WWWW), water, unfiltered, percent recovery',
#  'p62842': 'Fluoranthene-d10, surrogate, NWQL schedule 4433 and labcode 8033 (WWWW), water, unfiltered, percent recovery',
#  'p62854': 'Total nitrogen [nitrate + nitrite + ammonia + organic-N], water, filtered, analytically determined, milligrams per liter',
#  'p62855': 'Total nitrogen [nitrate + nitrite + ammonia + organic-N], water, unfiltered, analytically determined, milligrams per liter',
#  'p63041': 'delta oxygen-18/oxygen-16 of nitrate, water, filtered, per mil',
#  'p63145': '3,4-Dichlorophenyl isocyanate, water, unfiltered, recoverable, micrograms per liter',
#  'p63147': 'BDE congener 47, water, unfiltered, recoverable, micrograms per liter',
# ...
#  'p81551': 'Xylene (all isomers), water, unfiltered, recoverable, micrograms per liter',
#  'p81552': 'Acetone, water, unfiltered, recoverable, micrograms per liter',
#  'p81555': 'Bromobenzene, water, unfiltered, recoverable, micrograms per liter',
#  'p81563': 'Butane, water, unfiltered, recoverable, micrograms per liter',
#  'p81576': 'Diethyl ether, water, unfiltered, recoverable, micrograms per liter',
#  'p81577': 'Diisopropyl ether, water, unfiltered, recoverable, micrograms per liter',
#  'p81578': 'Dimethoxymethane, water, unfiltered, recoverable, micrograms per liter',
#  'p81582': '1,4-Dioxane, water, unfiltered, recoverable, micrograms per liter',
#  'p81583': '1,3-Dioxolane, water, unfiltered, recoverable, micrograms per liter',
#  'p81585': 'Ethyl acetate, water, unfiltered, recoverable, micrograms per liter',
#  'p81590': 'Hexane, water, unfiltered, recoverable, micrograms per liter',
#  'p81593': 'Methyl acrylonitrile, water, unfiltered, recoverable, micrograms per liter',
#  'p81595': 'Methyl ethyl ketone, water, unfiltered, recoverable, micrograms per liter',
#  'p81597': 'Methyl methacrylate, water, unfiltered, recoverable, micrograms per liter',
#  'p81604': 'n-Pentane, water, unfiltered, recoverable, micrograms per liter',
#  'p81607': 'Tetrahydrofuran, water, unfiltered, recoverable, micrograms per liter',
#  'p81696': '1-Methylnaphthalene, water, unfiltered, recoverable, micrograms per liter',
#  'p81757': 'Cyanazine, water, unfiltered, recoverable, micrograms per liter',
#  'p81886': "p,p'-Ethyl-DDD, bed sediment, recoverable, dry weight, micrograms per kilogram",
#  'p81903': 'Depth to bottom at sample location, feet',
#  'p82015': 'Mean depth of lake, feet',
#  'p82068': 'Potassium-40, water, filtered, picocuries per liter',
#  'p82081': 'delta carbon-13/carbon-12, water, unfiltered, per mil',
#  'p82082': 'delta hydrogen-2/hydrogen-1, water, unfiltered, per mil',
#  'p82085': 'delta oxygen-18/oxygen-16, water, unfiltered, per mil',
#  'p82184': 'Ametryn, water, unfiltered, recoverable, micrograms per liter',
#  'p82185': 'Atraton, water, unfiltered, recoverable, micrograms per liter',
#  'p82187': 'Cyprazine, water, unfiltered, recoverable, micrograms per liter',
#  'p82188': 'Simetone, water, unfiltered, recoverable, micrograms per liter',
#  'p82303': 'Radon-222, water, unfiltered, picocuries per liter',
#  'p82346': 'Ethion, water, filtered, recoverable, micrograms per liter',
#  'p82398': 'Sampling method, code',
#  'p82611': 'Metribuzin, water, unfiltered, recoverable, micrograms per liter',
#  'p82612': 'Metolachlor, water, unfiltered, recoverable, micrograms per liter',
#  'p82625': '1,2-Dibromo-3-chloropropane, water, unfiltered, recoverable, micrograms per liter',
#  'p82626': '1,2-Diphenylhydrazine, water, unfiltered, recoverable, micrograms per liter',
#  'p82630': 'Metribuzin, water, filtered, recoverable, micrograms per liter',
#  'p82660': '2,6-Diethylaniline, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82661': 'Trifluralin, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82662': 'Dimethoate, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82663': 'Ethalfluralin, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82664': 'Phorate, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82665': 'Terbacil, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82666': 'Linuron, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82667': 'Methyl parathion, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82668': 'EPTC, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82669': 'Pebulate, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82670': 'Tebuthiuron, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82671': 'Molinate, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82672': 'Ethoprop, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82673': 'Benfluralin, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82674': 'Carbofuran, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82675': 'Terbufos, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82676': 'Propyzamide, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82677': 'Disulfoton, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82678': 'Triallate, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82679': 'Propanil, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82680': 'Carbaryl, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82681': 'Thiobencarb, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82682': 'DCPA, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82683': 'Pendimethalin, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82684': 'Napropamide, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82685': 'Propargite, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82686': 'Azinphos-methyl, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82687': 'cis-Permethrin, water, filtered (0.7 micron glass fiber filter), recoverable, micrograms per liter',
#  'p82690': 'delta nitrogen-15/nitrogen-14 of nitrate, water, filtered, per mil',
#  'p82691': 'delta nitrogen-15/nitrogen-14 of ammonia, water, filtered, per mil',
#  'p82698': 'delta nitrogen-15/nitrogen-14 of dinitrogen, water, unfiltered, per mil',
#  'p82701': 'delta chromium-53/chromium-52, water, filtered, per mil',
#  'p82903': 'Depth to bottom from water surface, at sampling location, meters',
#  'p84164': 'Sampler type, code',
#  'p85561': 'Helium-4, water, dissolved, cubic centimeters per gram at standard temperature and pressure',
#  'p85562': 'Helium-4 error, water, unfiltered, cubic centimeters per gram at standard temperature and pressure',
#  'p85563': 'Argon, water, dissolved, cubic centimeters per gram at standard temperature and pressure',
#  'p85564': 'Argon error, water, unfiltered, cubic centimeters per gram at standard temperature and pressure',
#  'p85565': 'Krypton, water, dissolved, cubic centimeters per gram at standard temperature and pressure',
#  'p85566': 'Krypton error, water, unfiltered, cubic centimeters per gram at standard temperature and pressure',
#  'p85567': 'Xenon, water, dissolved, cubic centimeters per gram at standard temperature and pressure',
#  'p85568': 'Xenon error, water, unfiltered, cubic centimeters per gram at standard temperature and pressure',
#  'p85569': 'Helium-3/helium-4 error, water, unfiltered, ratio',
#  'p85668': '1-Chloro-1,1-difluoroethane, water, unfiltered, recoverable, micrograms per liter',
#  'p85795': 'm-Xylene plus p-xylene, water, unfiltered, recoverable, micrograms per liter',
#  'p90095': 'Specific conductance, water, unfiltered, laboratory, microsiemens per centimeter at 25 degrees Celsius',
#  'p90410': 'Acid neutralizing capacity, water, unfiltered, fixed endpoint (pH 4.5) titration, laboratory, milligrams per liter as calcium carbonate',
#  'p90576': '1-Bromo-3-chloropropane-d6, surrogate, water, unfiltered, percent recovery',
#  'p90607': 'Tetrahydrofuran-d8, surrogate, water, unfiltered, percent recovery',
#  'p90630': 'Phenol-d5, surrogate, NWQL schedules 1383/1385, water, unfiltered, percent recovery',
#  'p90640': 'Barban, surrogate, NWQL schedules 2060/9060, water, filtered, percent recovery',
#  'p90652': '2,4,6-Tribromophenol, surrogate, water, unfiltered, percent recovery',
#  'p90695': '1-Bromo-4-fluorobenzene, surrogate, water, unfiltered, ambient purge and trap method, percent recovery',
#  'p90696': 'Toluene-d8, surrogate, water, unfiltered, ambient purge and trap method, percent recovery',
#  'p90701': '1-Bromo-4-fluorobenzene, surrogate, water, unfiltered, ambient purge and trap method, percent recovery',
#  'p90703': 'Toluene-d8, surrogate, NWQL schedule 4437, water, unfiltered, percent recovery',
#  'p90737': 'Decafluorobiphenyl, surrogate, NWQL wastewater compound schedules (WCS), percent recovery',
#  'p90738': 'Fluoranthene-d10, surrogate, NWQL wastewater compound schedules (WCS), percent recovery',
#  'p90851': 'Trihalomethanes, water, unfiltered, minimum summation, micrograms per liter',
#  'p90867': 'Trihalomethanes, water, unfiltered, maximum summation, micrograms per liter',
#  'p90900': 'Total coliforms, MI MF method, water, colony forming units per 100 milliliters',
#  'p90901': 'Escherichia coli, MI MF method, water, colony forming units per 100 milliliters',
#  'p90902': 'Escherichia coli, modified m-TEC MF method, water, colony forming units per 100 milliliters',
#  'p90909': 'Enterococci, mEI MF method, water, colony forming units per 100 ml',
#  'p91002': 'Fluoride, water, filtered, micrograms per liter',
#  'p91063': 'Diazinon-d10, surrogate, water, filtered (0.7 micron glass fiber filter), percent recovery',
#  'p91065': 'alpha-HCH-d6, surrogate, water, filtered (0.7 micron glass fiber filter), percent recovery',
#  'p91100': 'Sample weight, NWQL wastewater compound schedules (WCS), wet weight, grams',
#  'p91621': '2-Fluorophenol, surrogate, water, unfiltered, percent recovery',
#  'p91738': 'Phenol-d5, surrogate, water, unfiltered, percent recovery',
#  'p91742': 'Caffeine-d9, surrogate, water, unfiltered, percent recovery',
#  'p91748': 'Bisphenol A-d14, surrogate, water, unfiltered, percent recovery',
#  'p91749': 'Bisphenol A-d14, surrogate, solids, recoverable, percent recovery',
#  'p91818': 'Toluene-d8, surrogate, EPA 524.2, water, unfiltered, percent recovery',
#  'p91819': 'N-Nitrosodimethylamine-d6, surrogate, water, unfiltered, percent recovery',
#  'p91820': 'Nitrobenzene-d5, surrogate, water, unfiltered, percent recovery',
#  'p91821': 'p-Terphenyl-d14, surrogate, water, unfiltered, percent recovery',
#  'p91822': '2-Fluorobiphenyl, surrogate, water, unfiltered, percent recovery',
#  'p91825': 'N-Nitrosodimethylamine (NDMA), spike, water, unfiltered, percent recovery',
#  'p95100': 'Conversion factor, number',
#  'p95200': 'Total cell count, water, cells per milliliter',
#  'p95902': 'Noncarbonate hardness, water, milligrams per liter as calcium carbonate',
#  'p96012': 'CHLAMYDOMONADACEAE      (3) USGS,ACL-74',
#  'p96013': 'CARTERIA                (4) USGS,ACL-74',
#  'p96014': 'CHLAMYDOMONAS           (4) USGS,ACL-74',
#  'p96015': 'CHLOROGONIUM            (4) USGS,ACL-74',
#  'p96016': 'LOBOMONAS               (4) USGS,ACL-74',
#  'p96028': 'PHACOTUS                (4) USGS,ACL-74',
#  'p96029': 'PTEROMONAS              (4) USGS,ACL-74',
#  'p96036': 'EUDORINA                (4) USGS,ACL-74',
#  'p96063': 'GLOEOCYSTIS             (4) USGS,ACL-74',
#  'p96086': 'ELAKATOTHRIX            (4) USGS,ACL-74',
#  'p96101': 'URONEMA                 (4) USGS,ACL-74',
#  'p96104': 'MICROSPORA              (4) USGS,ACL-74',
#  'p96117': 'STIGEOCLONIUM           (4) USGS,ACL-74',
#  'p96123': 'COLEOCHAETE             (4) USGS,ACL-74',
#  'p96140': 'CLADOPHORA              (4) USGS,ACL-74',
#  'p96151': 'OEDOGONIUM              (4) USGS,ACL-74',
#  'p96190': 'SCHROEDERIA             (4) USGS,ACL-74',
#  'p96197': 'PEDIASTRUM              (4) USGS,ACL-74',
#  'p96200': 'COELASTRUM              (4) USGS,ACL-74',
#  'p96202': 'ANKISTRODESMUS          (4) USGS,ACL-74',
#  'p96205': 'CHLORELLA               (4) USGS,ACL-74',
#  'p96207': 'CLOSTERIOPSIS           (4) USGS,ACL-74',
#  'p96209': 'DICTYOSPHAERIUM         (4) USGS,ACL-74',
#  'p96213': 'FRANCEIA                (4) USGS,ACL-74 -96203',
#  'p96215': 'KIRCHNERIELLA           (4) USGS,ACL-74',
#  'p96217': 'NEPHROCYTIUM            (4) USGS,ACL-74',
#  'p96218': 'OOCYSTIS                (4) USGS,ACL-74',
#  'p96223': 'QUADRIGULA              (4) USGS,ACL-74',
#  'p96225': 'SELENASTRUM             (4) USGS,ACL-74',
#  'p96226': 'TETRAEDRON              (4) USGS,ACL-74',
#  'p96230': 'CHODATELLA              (4) USGS,ACL-74',
#  'p96237': 'SCENEDESMACEAE          (3) USGS,ACL-74',
#  'p96238': 'ACTINASTRUM             (4) USGS,ACL-74',
#  'p96240': 'CRUCIGENIA              (4) USGS,ACL-74',
#  'p96243': 'SCENEDESMUS             (4) USGS,ACL-74',
#  'p96245': 'TETRASTRUM              (4) USGS,ACL-74',
#  'p96252': 'GOLENKINIA              (4) USGS,ACL-74',
#  'p96254': 'MICRACTINIUM            (4) USGS,ACL-74',
#  'p96312': 'CLOSTERIUM              (4) USGS,ACL-74',
#  'p96313': 'COSMARIUM               (4) USGS,ACL-74',
#  'p96327': 'STAURASTRUM             (4) USGS,ACL-74',
#  'p96387': 'EUGLENA                 (4) USGS,ACL-74',
#  'p96390': 'PHACUS                  (4) USGS,ACL-74',
#  'p96392': 'TRACHELOMONAS           (4) USGS,ACL-74',
#  'p96413': 'CHROOMONAS              (4) USGS,ACL-74',
#  'p96416': 'CRYPTOMONAS             (4) USGS,ACL-74',
#  'p96430': 'CRYPTOMONAS             (4) USGS,ACL-74 -96416',
#  'p96484': 'GLENODINIUM             (4) USGS,ACL-74',
#  'p96595': 'MALLOMONAS              (4) USGS,ACL-74',
#  'p96608': 'OCHROMONAS              (4) USGS,ACL-74',
#  'p96610': 'UROGLENOPSIS            (4) USGS,ACL-74',
#  'p96706': 'CYCLOTELLA              (4) USGS,ACL-74',
#  'p96707': 'MELOSIRA                (4) USGS,ACL-74',
#  'p96708': 'STEPHANODISCUS          (4) USGS,ACL-74',
#  'p96750': 'TABELLARIA              (4) USGS,ACL-74',
#  'p96756': 'MERIDION                (4) USGS,ACL-74',
#  'p96759': 'DIATOMA                 (4) USGS,ACL-74',
#  'p96764': 'FRAGILARIA              (4) USGS,ACL-74',
#  'p96765': 'SYNEDRA                 (4) USGS,ACL-74',
#  'p96777': 'ACHNANTHES              (4) USGS,ACL-74',
#  'p96778': 'COCCONEIS               (4) USGS,ACL-74',
#  'p96779': 'RHOICOSPHENIA           (4) USGS,ACL-75',
#  'p96787': 'DIPLONEIS               (4) USGS,ACL-74',
#  'p96791': 'NAVICULA                (4) USGS,ACL-74',
#  'p96802': 'GOMPHONEMA              (4) USGS,ACL-74',
#  'p96805': 'AMPHORA                 (4) USGS,ACL-74',
#  'p96806': 'CYMBELLA                (4) USGS,ACL-74',
#  'p96807': 'EPITHEMIA               (4) USGS,ACL-74',
#  'p96810': 'DENTICULA               (4) USGS,ACL-74',
#  'p96811': 'HANTZSCHIA              (4) USGS,ACL-74',
#  'p96812': 'NITZSCHIA               (4) USGS,ACL-74',
#  'p96817': 'SURIRELLA               (4) USGS,ACL-74',
#  'p98082': 'ANACYSTIS               (4) MENEGH,1837 -98066',
#  'p98090': 'AGMENELLUM              (4) BREB. ,1839',
#  'p98093': 'COCCOCHLORIS            (4) SPRENG,1827',
#  'p98131': "LYNGBYA                 (4) AGARD' ,1824",
#  'p98136': 'OSCILLATORIA            (4) VAUCHER,1803',
#  'p98142': 'PHORMIDIUM              (4)  KEUTZ,1843',
#  'p98165': 'ANABAENA                (4) USGS,ACL-74',
#  'p98166': 'ANABAENOPSIS            (4) USGS,ACL-74',
#  'p98167': 'APHANIZOMENON           (4) USGS,ACL-74',
#  'p98169': 'CYLINDROSPERMUM         (4) USGS,ACL-74',
#  'p98182': 'PLECTONEMA              (4) USGS,ACL-74',
#  'p99034': 'Inorganic arsenic(III), water, filtered (0.45 micron filter), micrograms per liter as arsenic',
#  'p99105': 'Type of replicate, code',
#  'p99111': 'Type of quality assurance data associated with sample, code',
#  'p99112': 'Topical quality-control data purpose, code',
#  'p99118': 'Sulfide, water, filtered, field, milligrams per liter',
#  'p99119': 'Sulfide, water, unfiltered, field, milligrams per liter',
#  'p99157': 'Hydrochloric acid NWIS lot number, 1:1 solution, 30 mL, National Field Supply Service (NFSS) stock number N1140',
#  'p99158': 'Hydrochloric acid NWIS lot number, 6 N (1:1), 2 mL, National Field Supply Service (NFSS) stock number Q446FLD',
#  ...}

# %%
filtered_params = {}
unfiletered_params = {}
collapsed_params_dict = {}
for param in params_dict.items():
    components = param[1].split(", ")
    component = components[0]
    if len(component) == 1:
        component = component + "," + components[1]
    if re.search(pattern="  +", string=component):
        component = component.split()[0]
        
    component = component.lower()
    if component not in collapsed_params_dict:
        collapsed_params_dict[component] = 0
    collapsed_params_dict[component] += 1
    
collapsed_params_dict

file = open("parameter_list.txt", "w")
for param in collapsed_params_dict:
    file.write(param + "\n")
file.close()
# Out:
# ----------------------------------------------------------------------
# IndexError                           Traceback (most recent call last)
# <ipython-input-16-72dc0424b943> in <module>()
#      15     collapsed_params_dict[component] += 1
#      16
# ---> 17     if components[2] == "filtered":
#      18         filtered_params[param[0]] = component
#      19     elif components[2] == "unfiltered":
#
# IndexError: list index out of range

# %%
a = pd.read_csv(pd.compat.StringIO(data[15]), sep='\t', low_memory=False, header=0, skiprows=[1])
# I find this a bit concerning...: https://stackoverflow.com/questions/24251219/pandas-read-csv-low-memory-and-dtype-options
# I'd want to specify type, but it seems like there's a lot of strings within supposedly numerical columns...
print(a.shape)
# Out:
# (7763, 1046)

# %%
display(a)
# Out:
#      agency_cd          site_no   sample_dt sample_tm sample_end_dt  \
# 0         USGS  332031118504001  2000-10-24     14:30           NaN
# 1         USGS  333420118060501  2000-11-09     09:30           NaN
# 2         USGS  333420118060501  2006-08-30     08:20           NaN
# 3         USGS  333420118060501  2006-08-30     08:30           NaN
# 4         USGS  333420118060501  2006-08-30     08:40           NaN
# 5         USGS  334607118053801  1995-08-30     15:25           NaN
# 6         USGS  334607118053901  1995-08-30     14:30           NaN
# 7         USGS  334626118043601  1956-04-18       NaN           NaN
# 8         USGS  334626118043601  1960-07-11       NaN           NaN
# 9         USGS  334637118172701  1999-03-19     09:30           NaN
# 10        USGS  334637118172701  2006-11-14     09:40           NaN
# 11        USGS  334637118172701  2006-11-14     09:50           NaN
# 12        USGS  334637118172701  2006-11-14     10:00           NaN
# 13        USGS  334650118150301  1999-03-06     16:15           NaN
# 14        USGS  334650118150302  1999-03-06     17:40           NaN
# 15        USGS  334654118141801  1999-02-10     16:00           NaN
# 16        USGS  334655118141801  1999-02-10     17:00           NaN
# 17        USGS  334656118162801  1999-02-06     11:45           NaN
# 18        USGS  334704118192601  2006-11-16     08:40           NaN
# 19        USGS  334704118192601  2006-11-16     08:50           NaN
# 20        USGS  334704118192601  2006-11-16     09:00           NaN
# 21        USGS  334706118143101  1999-02-25     15:00           NaN
# 22        USGS  334706118143103  1999-02-25     16:15           NaN
# 23        USGS  334706118171701  1999-03-07     13:10           NaN
# 24        USGS  334706118171702  1999-03-07     14:45           NaN
# 25        USGS  334710118145801  1999-03-09     13:40           NaN
# 26        USGS  334710118145802  1999-02-26     10:30           NaN
# 27        USGS  334712118124301  1999-03-18     17:00           NaN
# 28        USGS  334712118124302  1999-03-19     14:00           NaN
# 29        USGS  334720118133201  1999-02-11     18:05           NaN
# ...        ...              ...         ...       ...           ...
# 7733      USGS  335312118200706  2014-09-08     13:30           NaN
# 7734      USGS  335716118135101  2014-09-22     10:40           NaN
# 7735      USGS  335716118135106  2014-09-22     16:00           NaN
# 7736      USGS  335716118135102  2014-09-22     12:00           NaN
# 7737      USGS  335716118135103  2014-09-22     13:00           NaN
# 7738      USGS  335716118135104  2014-09-22     14:00           NaN
# 7739      USGS  335716118135105  2014-09-22     15:00           NaN
# 7740      USGS  335535118123906  2014-10-16     12:20           NaN
# 7741      USGS  335535118124001  2014-10-16     14:20           NaN
# 7742      USGS  335535118123901  2014-10-17     10:30           NaN
# 7743      USGS  335535118123902  2014-10-17     09:30           NaN
# 7744      USGS  335535118123903  2014-10-16     15:40           NaN
# 7745      USGS  335535118123904  2014-10-16     13:40           NaN
# 7746      USGS  335535118123905  2014-10-16     17:20           NaN
# 7747      USGS  335535118124003  2014-10-16     08:45           NaN
# 7748      USGS  335535118124002  2014-10-16     10:10           NaN
# 7749      USGS  343526118095501  2017-09-23     10:20           NaN
# 7750      USGS  343526118095501  2017-09-23     13:40           NaN
# 7751      USGS  343523118095501  2016-08-17     11:30           NaN
# 7752      USGS  343523118095501  2016-08-17     11:40           NaN
# 7753      USGS  343523118095501  2017-09-23     10:20           NaN
# 7754      USGS  343523118095501  2017-09-23     10:30           NaN
# 7755      USGS  340030118041201  2016-07-19     12:00           NaN
# 7756      USGS  340030118041202  2016-07-19     11:00           NaN
# 7757      USGS  340030118041204  2016-07-19     14:00           NaN
# 7758      USGS  340030118041203  2016-07-19     15:00           NaN
# 7759      USGS  340027118041502  2016-07-20     11:30           NaN
# 7760      USGS  340027118041503  2016-07-20     13:00           NaN
# 7761      USGS  340027118041504  2016-07-20     14:30           NaN
# 7762      USGS  340027118041501  2016-07-20     12:30           NaN
#
#      sample_end_tm sample_start_time_datum_cd tm_datum_rlbty_cd coll_ent_cd  \
# 0              NaN                        PDT                 T    USGS-WRD
# 1              NaN                        PST                 T    USGS-WRD
# 2              NaN                        PDT                 K    USGS-WRD
# 3              NaN                        PST                 K    USGS-WRD
# 4              NaN                        PDT                 K    USGS-WRD
# 5              NaN                        PDT                 T    USGS-WRD
# 6              NaN                        PDT                 T    USGS-WRD
# 7              NaN                        PST                 T         NaN
# 8              NaN                        PST                 T         NaN
# 9              NaN                        PST                 T    USGS-WRD
# 10             NaN                        PST                 K    USGS-WRD
# 11             NaN                        PST                 K    USGS-WRD
# 12             NaN                        PST                 K    USGS-WRD
# 13             NaN                        PST                 T    USGS-WRD
# 14             NaN                        PST                 T    USGS-WRD
# 15             NaN                        PST                 T    USGS-WRD
# 16             NaN                        PST                 T    USGS-WRD
# 17             NaN                        PST                 T    USGS-WRD
# 18             NaN                        PST                 K    USGS-WRD
# 19             NaN                        PST                 K    USGS-WRD
# 20             NaN                        PST                 K    USGS-WRD
# 21             NaN                        PST                 T    USGS-WRD
# 22             NaN                        PST                 T    USGS-WRD
# 23             NaN                        PST                 T    USGS-WRD
# 24             NaN                        PST                 T    USGS-WRD
# 25             NaN                        PST                 T    USGS-WRD
# 26             NaN                        PST                 T    USGS-WRD
# 27             NaN                        PST                 T    USGS-WRD
# 28             NaN                        PST                 T    USGS-WRD
# 29             NaN                        PST                 T    USGS-WRD
# ...            ...                        ...               ...         ...
# 7733           NaN                        PDT                 K    USGS-WRD
# 7734           NaN                        PDT                 K    USGS-WRD
# 7735           NaN                        PDT                 K    USGS-WRD
# 7736           NaN                        PDT                 K    USGS-WRD
# 7737           NaN                        PDT                 K    USGS-WRD
# 7738           NaN                        PDT                 K    USGS-WRD
# 7739           NaN                        PDT                 K    USGS-WRD
# 7740           NaN                        PDT                 K    USGS-WRD
# 7741           NaN                        PDT                 K    USGS-WRD
# 7742           NaN                        PDT                 K    USGS-WRD
# 7743           NaN                        PDT                 K    USGS-WRD
# 7744           NaN                        PDT                 K    USGS-WRD
# 7745           NaN                        PDT                 K    USGS-WRD
# 7746           NaN                        PDT                 K    USGS-WRD
# 7747           NaN                        PDT                 K    USGS-WRD
# 7748           NaN                        PDT                 K    USGS-WRD
# 7749           NaN                        PDT                 K    USGS-WRD
# 7750           NaN                        PDT                 K    USGS-WRD
# 7751           NaN                        PDT                 K    USGS-WRD
# 7752           NaN                        PDT                 K    USGS-WRD
# 7753           NaN                        PDT                 K    USGS-WRD
# 7754           NaN                        PDT                 K    USGS-WRD
# 7755           NaN                        PDT                 K         NaN
# 7756           NaN                        PDT                 K         NaN
# 7757           NaN                        PDT                 K    USGSCAWC
# 7758           NaN                        PDT                 K         NaN
# 7759           NaN                        PDT                 K    USGSCAWC
# 7760           NaN                        PDT                 K    USGSCAWC
# 7761           NaN                        PDT                 K    USGSCAWC
# 7762           NaN                        PDT                 K    USGSCAWC
#
#      medium_cd   ...    p99856  p99871  p99931  p99947  p99958  p99959  \
# 0           WG   ...       NaN     0.0     NaN     NaN     NaN     NaN
# 1           WG   ...       NaN     0.0     NaN     NaN     NaN     NaN
# 2           WG   ...       NaN     0.0     NaN     NaN     NaN     NaN
# 3           WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 4           WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 5           WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 6           WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7           WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 8           WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 9           WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 10          WG   ...       NaN    16.0     NaN     NaN     NaN     NaN
# 11          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 12          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 13          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 14          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 15          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 16          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 17          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 18          WG   ...       NaN     1.0     NaN     NaN     NaN     NaN
# 19          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 20          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 21          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 22          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 23          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 24          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 25          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 26          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 27          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 28          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 29          WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# ...        ...   ...       ...     ...     ...     ...     ...     ...
# 7733        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7734        WG   ...       NaN     0.0     NaN     NaN     NaN     NaN
# 7735        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7736        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7737        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7738        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7739        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7740        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7741        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7742        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7743        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7744        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7745        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7746        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7747        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7748        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7749        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7750        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7751        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7752        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7753        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7754        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7755        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7756        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7757        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7758        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7759        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7760        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7761        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
# 7762        WG   ...       NaN     NaN     NaN     NaN     NaN     NaN
#
#       p99963  p99972  p99994  p99995
# 0        NaN     NaN     NaN     NaN
# 1        NaN     NaN     NaN     NaN
# 2        NaN   973.0    90.7    99.8
# 3        NaN     NaN     NaN     NaN
# 4        NaN     NaN     NaN     NaN
# 5        NaN     NaN     NaN     NaN
# 6        NaN     NaN     NaN     NaN
# 7        NaN     NaN     NaN     NaN
# 8        NaN     NaN     NaN     NaN
# 9        NaN     NaN     NaN     NaN
# 10       NaN   943.0     123   101.0
# 11       NaN     NaN     NaN     NaN
# 12       NaN     NaN     NaN     NaN
# 13       NaN     NaN     NaN     NaN
# 14       NaN     NaN     NaN     NaN
# 15       NaN     NaN     NaN     NaN
# 16       NaN     NaN     NaN     NaN
# 17       NaN     NaN     NaN     NaN
# 18       NaN   978.0     111    90.6
# 19       NaN     NaN     NaN     NaN
# 20       NaN     NaN     NaN     NaN
# 21       NaN     NaN     NaN     NaN
# 22       NaN     NaN     NaN     NaN
# 23       NaN     NaN     NaN     NaN
# 24       NaN     NaN     NaN     NaN
# 25       NaN     NaN     NaN     NaN
# 26       NaN     NaN     NaN     NaN
# 27       NaN     NaN     NaN     NaN
# 28       NaN     NaN     NaN     NaN
# 29       NaN     NaN     NaN     NaN
# ...      ...     ...     ...     ...
# 7733     NaN     NaN     NaN     NaN
# 7734     NaN     NaN     NaN     NaN
# 7735     NaN     NaN     NaN     NaN
# 7736     NaN     NaN     NaN     NaN
# 7737     NaN     NaN     NaN     NaN
# 7738     NaN     NaN     NaN     NaN
# 7739     NaN     NaN     NaN     NaN
# 7740     NaN     NaN     NaN     NaN
# 7741     NaN     NaN     NaN     NaN
# 7742     NaN     NaN     NaN     NaN
# 7743     NaN     NaN     NaN     NaN
# 7744     NaN     NaN     NaN     NaN
# 7745     NaN     NaN     NaN     NaN
# 7746     NaN     NaN     NaN     NaN
# 7747     NaN     NaN     NaN     NaN
# 7748     NaN     NaN     NaN     NaN
# 7749     NaN     NaN     NaN     NaN
# 7750     NaN     NaN     NaN     NaN
# 7751     NaN     NaN     NaN     NaN
# 7752     NaN     NaN     NaN     NaN
# 7753     NaN     NaN     NaN     NaN
# 7754     NaN     NaN     NaN     NaN
# 7755     NaN     NaN     NaN     NaN
# 7756     NaN     NaN     NaN     NaN
# 7757     NaN     NaN     NaN     NaN
# 7758     NaN     NaN     NaN     NaN
# 7759     NaN     NaN     NaN     NaN
# 7760     NaN     NaN     NaN     NaN
# 7761     NaN     NaN     NaN     NaN
# 7762     NaN     NaN     NaN     NaN
#
# [7763 rows x 1046 columns]

# %%
# Let's see how much data we have for each parameter...
params_counts_dict = {}
for param in a:
    count = a.shape[0] - sum(a[param].isna())
    if count > 0:
        params_counts_dict[params_dict[param]] = count
    
    #print(params_dict[param] + ":", count)
params_counts = list(params_counts_dict.values())

# %%
plt.hist(list(params_counts_dict.values()))
# Out:
# (array([961.,  25.,  18.,   5.,  13.,   2.,   2.,   2.,   1.,   6.]),
#  array([1.0000e+00, 7.7720e+02, 1.5534e+03, 2.3296e+03, 3.1058e+03,
#         3.8820e+03, 4.6582e+03, 5.4344e+03, 6.2106e+03, 6.9868e+03,
#         7.7630e+03]),
#  <a list of 10 Patch objects>)

# %%
counts_of_counts = {}
for count in params_counts_dict.values():
    if count not in counts_of_counts:
        counts_of_counts[count] = 0
    counts_of_counts[count] += 1

param_counts = list(params_counts_dict.values())
count_counts = list(counts_of_counts.values())
bin_edges = np.logspace(np.log10(min(param_counts)), 
                        np.log10(max(param_counts)),
                        num = 10)
density, _ = np.histogram(param_counts, bins=bin_edges, density=True)

# %%
log_be = np.log10(bin_edges)
x = 10**((log_be[1:] + log_be[:-1])/2)

plt.loglog(x, density, marker='o', linestyle='none')

# %%
log_be
# Out:
# array([0.        , 0.43222551, 0.86445102, 1.29667653, 1.72890204,
#        2.16112755, 2.59335306, 3.02557857, 3.45780408, 3.89002959])

# %% [markdown]
# filter vs unfiltered
# * unfiltered = grab the ground water as is - you have extra sediment somehow
# * filtered = you filter out the ground water
# * do analysis with filtered and unfiltered, but DON'T MIX
# * higher pollution for unfiltered properties

# %%
filtered_params = {}
unfiltered_params = {}
for param in params_dict.items():
    components = param[1].split(", ")
    if "filtered" in components or "unfiltered" in components:
        component = components[0]
        if components[2] == "filtered":
            if component not in filtered_params:
                filtered_params[component] = []
            filtered_params[component].append(param[0])
        elif components[2] == "unfiltered":
            if component not in unfiltered_params:
                unfiltered_params[component] = []
            unfiltered_params[component].append(param[0])

# %%
filtered_params
# Out:
# {'Color': ['p00080'],
#  'Carbonate': ['p00452', 'p29807', 'p63788'],
#  'Bicarbonate': ['p00453', 'p29804', 'p63786'],
#  'Dissolved solids dried at 105 degrees Celsius': ['p00515'],
#  'Loss on ignition of dissolved solids': ['p00520'],
#  'Total nitrogen [nitrate + nitrite + ammonia + organic-N]': ['p00602',
#   'p62854'],
#  'Organic nitrogen': ['p00607'],
#  'Ammonia (NH3 + NH4+)': ['p00608', 'p71846'],
#  'Nitrite': ['p00613', 'p71856'],
#  'Nitrate': ['p00618', 'p71851'],
#  'Ammonia plus organic nitrogen': ['p00623'],
#  'Nitrate plus nitrite': ['p00631'],
#  'Orthophosphate': ['p00660', 'p00671'],
#  'Phosphorus': ['p00666'],
#  'Organic carbon': ['p00681'],
#  'Sulfide': ['p00746', 'p99118'],
#  'Noncarbonate hardness': ['p00904', 'p00905'],
#  'Calcium': ['p00915'],
#  'Magnesium': ['p00925'],
#  'Sodium': ['p00930'],
#  'Sodium plus potassium': ['p00933'],
#  'Potassium': ['p00935'],
#  'Chloride': ['p00940'],
#  'Sulfate': ['p00945'],
#  'Fluoride': ['p00950', 'p91002'],
#  'Silica': ['p00955'],
#  'Arsenic': ['p01000'],
#  'Barium': ['p01005'],
#  'Beryllium': ['p01010'],
#  'Boron': ['p01020'],
#  'Cadmium': ['p01025'],
#  'Chromium': ['p01030'],
#  'Chromium(VI)': ['p01032'],
#  'Cobalt': ['p01035'],
#  'Copper': ['p01040'],
#  'Iron': ['p01046'],
#  'Iron(II)': ['p01047'],
#  'Iron(II) plus Iron(III)': ['p01048'],
#  'Lead': ['p01049'],
#  'Manganese': ['p01056'],
#  'Thallium': ['p01057'],
#  'Molybdenum': ['p01060'],
#  'Nickel': ['p01065'],
#  'Silver': ['p01075'],
#  'Strontium': ['p01080'],
#  'Vanadium': ['p01085'],
#  'Zinc': ['p01090'],
#  'Antimony': ['p01095'],
#  'Aluminum': ['p01106'],
#  'Lithium': ['p01130'],
#  'Selenium': ['p01145'],
#  'Tungsten': ['p01155'],
#  'Terbuthylazine': ['p04022'],
#  'Propachlor': ['p04024'],
#  'Hexazinone': ['p04025'],
#  'Butylate': ['p04028'],
#  'Bromacil': ['p04029'],
#  'Cycloate': ['p04031'],
#  'Terbacil': ['p04032'],
#  'Diphenamid': ['p04033'],
#  'Simazine': ['p04035'],
#  'Prometryn': ['p04036'],
#  'Prometon': ['p04037'],
#  '2-Chloro-6-ethylamino-4-amino-s-triazine': ['p04038'],
#  '2-Chloro-4-isopropylamino-6-amino-s-triazine': ['p04040'],
#  'Cyanazine': ['p04041'],
#  'Fonofos': ['p04095'],
#  'Radium-226': ['p09503', 'p09511'],
#  'Uranium-238': ['p22603'],
#  'Uranium-234': ['p22610'],
#  'Uranium-235': ['p22620'],
#  'Uranium (natural)': ['p22703'],
#  'Alkalinity': ['p29801', 'p29802', 'p39036', 'p39086'],
#  'alpha-HCH': ['p34253'],
#  'alpha-Endosulfan': ['p34362'],
#  "p,p'-DDE": ['p34653'],
#  'Dicrotophos': ['p38454'],
#  'Siduron': ['p38548'],
#  'Dichlorvos': ['p38775'],
#  'Chlorpyrifos': ['p38933'],
#  'Lindane': ['p39341'],
#  'Dieldrin': ['p39381'],
#  'Metolachlor': ['p39415'],
#  'Malathion': ['p39532'],
#  'Parathion': ['p39542'],
#  'Diazinon': ['p39572'],
#  'Atrazine': ['p39632'],
#  '2,4-D': ['p39732'],
#  '2,4,5-T': ['p39742'],
#  'Silvex': ['p39762'],
#  'Alachlor': ['p46342'],
#  'Acetochlor': ['p49260'],
#  'delta sulfur-34/sulfur-32 of sulfate': ['p49932'],
#  'Carbon-14': ['p49933'],
#  'Carbon-14 counting error': ['p49934'],
#  'Bendiocarb': ['p50299'],
#  'Benomyl': ['p50300'],
#  'Caffeine': ['p50305'],
#  'Chlorimuron-ethyl': ['p50306'],
#  'Sulfometuron-methyl': ['p50337'],
#  '2-Hydroxy-4-isopropylamino-6-ethylamino-s-triazine': ['p50355'],
#  'Imazaquin': ['p50356'],
#  'Metalaxyl': ['p50359', 'p61596'],
#  'Nicosulfuron': ['p50364'],
#  'Imazethapyr': ['p50407'],
#  '2,4-D methyl ester': ['p50470'],
#  'Propiconazole': ['p50471'],
#  'Radium-224': ['p50833'],
#  'Tribenuron-methyl': ['p61159'],
#  'Chloramben methyl ester': ['p61188'],
#  'Cyfluthrin': ['p61585'],
#  'Cypermethrin': ['p61586'],
#  'Endosulfan sulfate': ['p61590'],
#  'Fenamiphos': ['p61591'],
#  'Iprodione': ['p61593'],
#  'Isofenphos': ['p61594'],
#  'lambda-Cyhalothrin': ['p61595'],
#  'Methidathion': ['p61598'],
#  'Myclobutanil': ['p61599'],
#  'Oxyfluorfen': ['p61600'],
#  'Phosmet': ['p61601'],
#  'Tefluthrin': ['p61606'],
#  'Tribufos': ['p61610'],
#  "2-Chloro-2',6'-diethylacetanilide": ['p61618'],
#  '2-Ethyl-6-methylaniline': ['p61620'],
#  '3,4-Dichloroaniline': ['p61625'],
#  '3,5-Dichloroaniline': ['p61627'],
#  '4-Chloro-2-methylphenol': ['p61633'],
#  'Azinphos-methyl oxygen analog': ['p61635'],
#  'Chlorpyrifos oxygen analog': ['p61636'],
#  'Diazoxon': ['p61638'],
#  'Disulfoton sulfone': ['p61640'],
#  'Ethion monoxon': ['p61644'],
#  'Fenamiphos sulfone': ['p61645'],
#  'Fenamiphos sulfoxide': ['p61646'],
#  'Malaoxon': ['p61652'],
#  'Methyl paraoxon': ['p61664'],
#  'Phorate oxygen analog': ['p61666'],
#  'Phosmet oxygen analog': ['p61668'],
#  'Terbufos oxygen analog sulfone': ['p61674'],
#  "N-(4-Chlorophenyl)-N'-methylurea": ['p61692'],
#  'Bensulfuron-methyl': ['p61693'],
#  'Flumetsulam': ['p61694'],
#  'Imidacloprid': ['p61695'],
#  'Metsulfuron-methyl': ['p61697'],
#  'Acetaminophen': ['p62000'],
#  'Codeine': ['p62003'],
#  'Dehydronifedipine': ['p62004'],
#  'Cotinine': ['p62005'],
#  'Diltiazem': ['p62008'],
#  'Albuterol': ['p62020'],
#  'Sulfamethoxazole': ['p62021'],
#  'Trimethoprim': ['p62023'],
#  'Warfarin': ['p62024'],
#  '1,7-Dimethylxanthine': ['p62030'],
#  'Fipronil': ['p62166'],
#  'Fipronil sulfide': ['p62167'],
#  'Fipronil sulfone': ['p62168'],
#  'Desulfinylfipronil amide': ['p62169'],
#  'Desulfinylfipronil': ['p62170'],
#  'Arsenite': ['p62452'],
#  'delta boron-11/boron-10': ['p62648'],
#  'Carbamazepine': ['p62793'],
#  'Diphenhydramine': ['p62796'],
#  'Thiabendazole': ['p62801'],
#  'delta oxygen-18/oxygen-16 of nitrate': ['p63041'],
#  'Hydrophobic acid fraction of dissolved organic carbon': ['p63737'],
#  'Hydrophilic acid fraction of dissolved organic carbon': ['p63738'],
#  'Transphilic organic acid fraction of dissolved organic carbon': ['p63739'],
#  'Specific UV absorbance at 254 nm of hydrophobic acid fraction of DOC': ['p63742'],
#  'Specific UV absorbance at 254 nm of hydrophilic acid fraction of DOC': ['p63743'],
#  'Specific UV absorbance at 254 nm of transphilic organic acid fraction of DOC': ['p63744'],
#  'Perchlorate': ['p63790'],
#  'Dissolved solids dried at 180 degrees Celsius': ['p70300'],
#  'Dissolved solids': ['p70301', 'p70303'],
#  'Hydroxide': ['p71834'],
#  'Iodide': ['p71865'],
#  'Bromide': ['p71870'],
#  'Mercury': ['p71890'],
#  'Strontium-87/strontium-86 ratio': ['p75978'],
#  'cis-Propiconazole': ['p79846'],
#  'trans-Propiconazole': ['p79847'],
#  'Radium-228': ['p81366'],
#  'Potassium-40': ['p82068'],
#  'Ethion': ['p82346'],
#  'Metribuzin': ['p82630'],
#  'delta nitrogen-15/nitrogen-14 of nitrate': ['p82690'],
#  'delta nitrogen-15/nitrogen-14 of ammonia': ['p82691'],
#  'delta chromium-53/chromium-52': ['p82701']}

# %%
unfiltered_file = open("Unfiltered_params.txt", "w")
filtered_file = open("Filtered_params.txt", "w")

for param in unfiltered_params.items():
    formatSTR = param[0] + "\t" + "\t".join(param[1]) + "\r\n"
    unfiltered_file.write(formatSTR.lower())
unfiltered_file.close()
for param in filtered_params.items():
    formatSTR = param[0] + "\t" + "\t".join(param[1]) + "\r\n"
    filtered_file.write(formatSTR.lower())
filtered_file.close()

# %%
unfiltered_params["Turbidity"]
# Out:
# ['p00070', 'p00075', 'p00076', 'p61028', 'p63675', 'p63676', 'p63680']

# %%
for p in unfiltered_params["Turbidity"]:
    print(params_dict[p])
# Out:
# Turbidity, water, unfiltered, Jackson Turbidity Units
# Turbidity, water, unfiltered, Hellige turbidimeter, milligrams per liter as silicon dioxide
# Turbidity, water, unfiltered, nephelometric turbidity units
# Turbidity, water, unfiltered, field, nephelometric turbidity units
# Turbidity, water, unfiltered, broad band light source (400-680 nm), detection angle 90 +-30 degrees to incident light, nephelometric turbidity units (NTU)
# Turbidity, water, unfiltered, broad band light source (400-680 nm), detectors at multiple angles including 90 +-30 degrees, ratiometric correction, NTRU
# Turbidity, water, unfiltered, monochrome near infra-red LED light, 780-900 nm, detection angle 90 +-2.5 degrees, formazin nephelometric units (FNU)

# %%
thresholds = pd.ExcelFile("Pollutant_Thresholds_human_health.xlsx")
thresholds_data = thresholds.

# %%
data[15].split("\n")[1]
# Out:
# '5s\t15s\t10d\t5d\t10d\t5d\t3s\t1s\t8s\t3s\t11s\t11s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t12s\t1 ...
